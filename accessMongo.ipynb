# %%
import pymongo
import pandas as pd

# %%
myclient = pymongo.MongoClient("mongodb+srv://shrey-viz:vizpass@cluster-mongo.pfwee.mongodb.net/confstudy?retryWrites=true&w=majority")

# %%
mydb = myclient["confstudy"]

# %%
mycollection = mydb["confstudy3"]

# %%
docs = mycollection.find()

docs_coll = {}
docs_list = []
count = 1
for d in docs:
    docs_coll[count] = d
    count = count + 1

# %%
## It starts from 117 to 128. 121 & 125 are a not complete
docs_coll[128]
# Out:
# {'_id': ObjectId('62adc5e962c20f22bf529d98'),
#  'usertoken': 'Ku6OCxxY',
#  'variables': [[['Immigrant population', 'Crime rate'], 'Countries'],
#   [['Avg. hours on social media', 'Depression severity'], 'People'],
#   [['Years of education', 'Income'], 'People']],
#  'timerArr': [{'timerV': '1'}, {'timerV': '2'}],
#  'responses': [{'belief': '-0.18859151990415102',
#    'uncertainty': ['-0.4245731950604483', '0.04739015525214629'],
#    'startTime': '1655555786864',
#    'endTime': '1655555804277',
#    'state': 'draw1',
#    'variables': [['Immigrant population', 'Crime rate'], 'Countries']},
#   {'startTime': '1655555805049',
#    'endTime': '1655555817324',
#    'dataShown': [{'x': '0.5257452956089932', 'y': '0.2518954797525801'},
#     {'x': '0.2953769508747319', 'y': '-0.3521018077535428'},
#     {'x': '0.9020530189635383', 'y': '0.18819620309001592'},
#     {'x': '2.192784011159438', 'y': '0.9205631455391532'},
#     {'x': '0.36759681483728834', 'y': '0.6290595825794367'},
# ...

# %%
with open("data_belief_persist.txt", 'w') as f: 
    f.write(str(docs_coll[117]))
    f.write("\n\n\n")
    f.write(str(docs_coll[118]))
    f.write("\n\n\n")
    f.write(str(docs_coll[119]))
    f.write("\n\n\n")
    f.write(str(docs_coll[120]))
    f.write("\n\n\n")
    f.write(str(docs_coll[122]))
    f.write("\n\n\n")
    f.write(str(docs_coll[123]))
    f.write("\n\n\n")
    f.write(str(docs_coll[124]))
    f.write("\n\n\n")
    f.write(str(docs_coll[126]))
    f.write("\n\n\n")
    f.write(str(docs_coll[127]))
    f.write("\n\n\n")
    f.write(str(docs_coll[128]))

# %%
import json
docs_list = [str(docs_coll[117]), str(docs_coll[118]), str(docs_coll[119]), str(docs_coll[120]), str(docs_coll[122]), str(docs_coll[123]), 
            str(docs_coll[124]), str(docs_coll[126]), str(docs_coll[127]), str(docs_coll[128])]
with open('data_pilot1.json', 'w') as fp:
    json.dump(docs_list, fp)

# %%
dict_item = docs_coll[120]
response_dict = dict_item['responses']
response_dict
# Out:
# [{'belief': '0.0828808419460858',
#   'uncertainty': ['-0.31825523266462286', '0.48401691655679424'],
#   'startTime': '1655553797383',
#   'endTime': '1655553820489',
#   'state': 'draw1',
#   'variables': [['Immigrant population', 'Crime rate'], 'Countries']},
#  {'startTime': '1655553821422',
#   'endTime': '1655553834712',
#   'dataShown': [{'x': '-0.4301127377647764', 'y': '-0.9016721253864765'},
#    {'x': '-0.16493587611094762', 'y': '1.126442105857244'},
#    {'x': '0.2660529949107219', 'y': '0.3631718808018699'},
#    {'x': '-0.21146090183672034', 'y': '-0.2369444877639492'},
#    {'x': '2.255243843616479', 'y': '-1.80959177420696'},
#    {'x': '0.156242850769011', 'y': '0.8147950933629313'},
#    {'x': '0.19218171686224858', 'y': '0.5139531975038161'},
#    {'x': '-0.5049873985687137', 'y': '1.2158902547050976'},
#    {'x': '-0.7267523018536262', 'y': '0.9641719266993429'},
#    {'x': '1.402157967426726', 'y': '-0.5490736458846378'},
# ...

# %%
## 0: Prior 1: Data; 2,3; 4,5; 6,7,8:Posterior
response_dict[1]
# Out:
# {'startTime': '1655553821422',
#  'endTime': '1655553834712',
#  'dataShown': [{'x': '-0.4301127377647764', 'y': '-0.9016721253864765'},
#   {'x': '-0.16493587611094762', 'y': '1.126442105857244'},
#   {'x': '0.2660529949107219', 'y': '0.3631718808018699'},
#   {'x': '-0.21146090183672034', 'y': '-0.2369444877639492'},
#   {'x': '2.255243843616479', 'y': '-1.80959177420696'},
#   {'x': '0.156242850769011', 'y': '0.8147950933629313'},
#   {'x': '0.19218171686224858', 'y': '0.5139531975038161'},
#   {'x': '-0.5049873985687137', 'y': '1.2158902547050976'},
#   {'x': '-0.7267523018536262', 'y': '0.9641719266993429'},
#   {'x': '1.402157967426726', 'y': '-0.5490736458846378'},
#   {'x': '-0.40692944745837806', 'y': '-0.4048635252633092'},
#   {'x': '-0.7813185199097707', 'y': '1.2244276806661425'},
#   {'x': '-1.572405179183507', 'y': '1.2162504918224555'},
#   {'x': '0.487221145077251', 'y': '0.45146065309205313'},
#   {'x': '-0.8959955559975283', 'y': '0.5763814893040518'},
# ...

# %%
response_dict[8]
# Out:
# {'belief': '-0.32068477615664825',
#  'uncertainty': ['-1', '0.464139425325685'],
#  'startTime': '1655554193100',
#  'endTime': '1655554202284',
#  'state': 'draw2',
#  'variables': [['Years of education', 'Income'], 'People']}

# %%
dict_item['retroResponses']
# Out:
# [{'retroReasonVal_1': "I figured there wasn't much relationship between immigrant population and crime rate.",
#   'retroReasonVal_2': 'I changed my graph to better represent the supporting data.'},
#  {'retroReasonVal_1': 'I thought high average hours on social media would correlate to high depression.',
#   'retroReasonVal_2': 'I completely misread the scatter plot however my original belief stands.'},
#  {'retroReasonVal_1': 'I would think low years of education would go with low income, and vice versa, but with a large variation.',
#   'retroReasonVal_2': 'I changed my response to correspond with the scatter plot.'}]

# %%
dict_item['retroResponses'][2]['retroReasonVal_2']
# Out:
# 'I changed my response to correspond with the scatter plot.'

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['ID'] = [docs_coll[120]['_id']]
df['usertoken'] = [docs_coll[120]['usertoken']]
df['prolificID'] = [docs_coll[120]['prequestionnaire']['profID']]
df['gender'] = [docs_coll[120]['prequestionnaire']['genderRadios']]
df['age'] = [docs_coll[120]['prequestionnaire']['age']]
df['race'] = [docs_coll[120]['prequestionnaire']['raceRadios']]
df['education'] = [docs_coll[120]['prequestionnaire']['eduRadios']]

df['variables_1'] = [docs_coll[120]['variables'][0]]
df['variables_2'] = [docs_coll[120]['variables'][1]]
df['variables_3'] = [docs_coll[120]['variables'][2]]
df['timerVal_1'] = [docs_coll[120]['timerArr'][0]['timerV']]
df['timerVal_2'] = [docs_coll[120]['timerArr'][1]['timerV']]

df['prior_belief_1'] = [docs_coll[120]['responses'][0]['belief']]
df['prior_uncertainty_1_L'] = [docs_coll[120]['responses'][0]['uncertainty'][0]]
df['prior_uncertainty_1_R'] = [docs_coll[120]['responses'][0]['uncertainty'][1]]
df['data_rho_1'] = [docs_coll[120]['responses'][1]['rhoBoot']['pearsonr']]
df['data_CI_1_L'] = [docs_coll[120]['responses'][1]['rhoBoot']['CI'][0]]
df['data_CI_1_R'] = [docs_coll[120]['responses'][1]['rhoBoot']['CI'][1]]
df['post_belief_1'] = [docs_coll[120]['responses'][6]['belief']]
df['post_uncertainty_1_L'] = [docs_coll[120]['responses'][6]['uncertainty'][0]]
df['post_uncertainty_1_R'] = [docs_coll[120]['responses'][6]['uncertainty'][1]]

df['prior_belief_2'] = [docs_coll[120]['responses'][2]['belief']]
df['prior_uncertainty_2_L'] = [docs_coll[120]['responses'][2]['uncertainty'][0]]
df['prior_uncertainty_2_R'] = [docs_coll[120]['responses'][2]['uncertainty'][1]]
df['data_rho_2'] = [docs_coll[120]['responses'][3]['rhoBoot']['pearsonr']]
df['data_CI_2_L'] = [docs_coll[120]['responses'][3]['rhoBoot']['CI'][0]]
df['data_CI_2_R'] = [docs_coll[120]['responses'][3]['rhoBoot']['CI'][1]]
df['post_belief_2'] = [docs_coll[120]['responses'][7]['belief']]
df['post_uncertainty_2_L'] = [docs_coll[120]['responses'][7]['uncertainty'][0]]
df['post_uncertainty_2_R'] = [docs_coll[120]['responses'][7]['uncertainty'][1]]

df['prior_belief_3'] = [docs_coll[120]['responses'][4]['belief']]
df['prior_uncertainty_3_L'] = [docs_coll[120]['responses'][4]['uncertainty'][0]]
df['prior_uncertainty_3_R'] = [docs_coll[120]['responses'][4]['uncertainty'][1]]
df['data_rho_3'] = [docs_coll[120]['responses'][5]['rhoBoot']['pearsonr']]
df['data_CI_3_L'] = [docs_coll[120]['responses'][5]['rhoBoot']['CI'][0]]
df['data_CI_3_R'] = [docs_coll[120]['responses'][5]['rhoBoot']['CI'][1]]
df['post_belief_3'] = [docs_coll[120]['responses'][8]['belief']]
df['post_uncertainty_3_L'] = [docs_coll[120]['responses'][8]['uncertainty'][0]]
df['post_uncertainty_3_R'] = [docs_coll[120]['responses'][8]['uncertainty'][1]]

df['retro_1_prior'] = [docs_coll[120]['retroResponses'][0]['retroReasonVal_1']]
df['retro_1_post'] = [docs_coll[120]['retroResponses'][0]['retroReasonVal_2']]
df['retro_2_prior'] = [docs_coll[120]['retroResponses'][1]['retroReasonVal_1']]
df['retro_2_post'] = [docs_coll[120]['retroResponses'][1]['retroReasonVal_2']]
df['retro_3_prior'] = [docs_coll[120]['retroResponses'][2]['retroReasonVal_1']]
df['retro_3_post'] = [docs_coll[120]['retroResponses'][2]['retroReasonVal_2']]

df
# Out:
#                          ID usertoken                prolificID  gender age  \
# 0  62adbe2462c20f22bf529d0f  PXU5f42K  5d810f6e58a1e20001287382  female  38
#
#     race education                                      variables_1  \
# 0  white     other  [[Immigrant population, Crime rate], Countries]
#
#                                          variables_2  \
# 0  [[Avg. hours on social media, Depression sever...
#
#                               variables_3  ...          data_CI_3_R  \
# 0  [[Years of education, Income], People]  ...  -0.3952391617995297
#
#           post_belief_3 post_uncertainty_3_L post_uncertainty_3_R  \
# 0  -0.32068477615664825                   -1    0.464139425325685
#
#                                        retro_1_prior  \
# 0  I figured there wasn't much relationship betwe...
#
#                                         retro_1_post  \
# 0  I changed my graph to better represent the sup...
#
#                                        retro_2_prior  \
# ...

# %%
cols = ['ID', 'usertoken', 'prolificID', 'gender', 'age', 'race', 'education', 'variables_1', 'variables_2', 'variables_3', 'timerVal_1',
       'timerVal_2', 'prior_belief_1', 'prior_uncertainty_1_L', 'prior_uncertainty_1_R', 'data_rho_1', 'data_CI_1_L', 'data_CI_1_R', 'post_belief_1',
       'post_uncertainty_1_L', 'post_uncertainty_1_R', 'prior_belief_2', 'prior_uncertainty_2_L', 'prior_uncertainty_2_R', 'data_rho_2', 'data_CI_2_L',
       'data_CI_2_R', 'post_belief_2', 'post_uncertainty_2_L', 'post_uncertainty_2_R', 'prior_belief_3', 'prior_uncertainty_3_L', 'prior_uncertainty_3_R',
       'data_rho_3', 'data_CI_3_L', 'data_CI_3_R', 'post_belief_3', 'post_uncertainty_3_L', 'post_uncertainty_3_R', 'retro_1_prior', 'retro_1_post', 
       'retro_2_prior', 'retro_2_post', 'retro_3_prior', 'retro_3_post']

df = pd.DataFrame(columns=cols , index=range(10))

c = 0
for idx in range(117, 129):
    if idx == 121 or idx == 125:
        continue
        
    df.loc[c].ID = docs_coll[idx]['_id']
    df.loc[c].usertoken = docs_coll[idx]['usertoken']
    df.loc[c].prolificID = docs_coll[idx]['prequestionnaire']['profID']
    df.loc[c].gender = docs_coll[idx]['prequestionnaire']['genderRadios']
    df.loc[c].age = docs_coll[idx]['prequestionnaire']['age']
    df.loc[c].race = docs_coll[idx]['prequestionnaire']['raceRadios']
    df.loc[c].education = docs_coll[idx]['prequestionnaire']['eduRadios']

    df.loc[c].variables_1 = docs_coll[idx]['variables'][0]
    df.loc[c].variables_2 = docs_coll[idx]['variables'][1]
    df.loc[c].variables_3 = docs_coll[idx]['variables'][2]
    df.loc[c].timerVal_1 = docs_coll[idx]['timerArr'][0]['timerV']
    df.loc[c].timerVal_2 = docs_coll[idx]['timerArr'][1]['timerV']

    df.loc[c].prior_belief_1 = docs_coll[idx]['responses'][0]['belief']
    df.loc[c].prior_uncertainty_1_L = docs_coll[idx]['responses'][0]['uncertainty'][0]
    df.loc[c].prior_uncertainty_1_R = docs_coll[idx]['responses'][0]['uncertainty'][1]
    df.loc[c].data_rho_1 = docs_coll[idx]['responses'][1]['rhoBoot']['pearsonr']
    df.loc[c].data_CI_1_L = docs_coll[idx]['responses'][1]['rhoBoot']['CI'][0]
    df.loc[c].data_CI_1_R = docs_coll[idx]['responses'][1]['rhoBoot']['CI'][1]
    df.loc[c].post_belief_1 = docs_coll[idx]['responses'][6]['belief']
    df.loc[c].post_uncertainty_1_L = docs_coll[idx]['responses'][6]['uncertainty'][0]
    df.loc[c].post_uncertainty_1_R = docs_coll[idx]['responses'][6]['uncertainty'][1]

    df.loc[c].prior_belief_2 = docs_coll[idx]['responses'][2]['belief']
    df.loc[c].prior_uncertainty_2_L = docs_coll[idx]['responses'][2]['uncertainty'][0]
    df.loc[c].prior_uncertainty_2_R = docs_coll[idx]['responses'][2]['uncertainty'][1]
    df.loc[c].data_rho_2 = docs_coll[idx]['responses'][3]['rhoBoot']['pearsonr']
    df.loc[c].data_CI_2_L = docs_coll[idx]['responses'][3]['rhoBoot']['CI'][0]
    df.loc[c].data_CI_2_R = docs_coll[idx]['responses'][3]['rhoBoot']['CI'][1]
    df.loc[c].post_belief_2 = docs_coll[idx]['responses'][7]['belief']
    df.loc[c].post_uncertainty_2_L = docs_coll[idx]['responses'][7]['uncertainty'][0]
    df.loc[c].post_uncertainty_2_R = docs_coll[idx]['responses'][7]['uncertainty'][1]

    df.loc[c].prior_belief_3 = docs_coll[idx]['responses'][4]['belief']
    df.loc[c].prior_uncertainty_3_L = docs_coll[idx]['responses'][4]['uncertainty'][0]
    df.loc[c].prior_uncertainty_3_R = docs_coll[idx]['responses'][4]['uncertainty'][1]
    df.loc[c].data_rho_3 = docs_coll[idx]['responses'][5]['rhoBoot']['pearsonr']
    df.loc[c].data_CI_3_L = docs_coll[idx]['responses'][5]['rhoBoot']['CI'][0]
    df.loc[c].data_CI_3_R = docs_coll[idx]['responses'][5]['rhoBoot']['CI'][1]
    df.loc[c].post_belief_3 = docs_coll[idx]['responses'][8]['belief']
    df.loc[c].post_uncertainty_3_L = docs_coll[idx]['responses'][8]['uncertainty'][0]
    df.loc[c].post_uncertainty_3_R = docs_coll[idx]['responses'][8]['uncertainty'][1]

    df.loc[c].retro_1_prior = docs_coll[idx]['retroResponses'][0]['retroReasonVal_1']
    df.loc[c].retro_1_post = docs_coll[idx]['retroResponses'][0]['retroReasonVal_2']
    df.loc[c].retro_2_prior = docs_coll[idx]['retroResponses'][1]['retroReasonVal_1']
    df.loc[c].retro_2_post = docs_coll[idx]['retroResponses'][1]['retroReasonVal_2']
    df.loc[c].retro_3_prior = docs_coll[idx]['retroResponses'][2]['retroReasonVal_1']
    df.loc[c].retro_3_post = docs_coll[idx]['retroResponses'][2]['retroReasonVal_2']
    
    c = c+ 1

# %%
df
# Out:
#                          ID usertoken                prolificID  gender age  \
# 0  62adb9c562c20f22bf529cda  E2vOrKUh  5dc2cbba034b451e7bd05f14  female  48
# 1  62adbaf762c20f22bf529cdf  cFcoW8NJ  5d487f57a1cf350016cb3c76    male  28
# 2  62adbbef62c20f22bf529ced  9xTjPfa9  61602d371599d54a4e61545c    male  36
# 3  62adbe2462c20f22bf529d0f  PXU5f42K  5d810f6e58a1e20001287382  female  38
# 4  62adbea062c20f22bf529d18  Czqn13VW  5eaaa3dd401ccb01e69eadc8    male  40
# 5  62adbf4162c20f22bf529d20  Y31nRDlA  5becfeed4f191100013b46db  female  43
# 6  62adbf6b62c20f22bf529d25  TYd86Fjb  6101f4493ed452ae3b6d5abf  female  42
# 7  62adc03962c20f22bf529d40  u0csEMqS  60c3aa01f9f6e994d8d7a273    male  26
# 8  62adc07762c20f22bf529d48  JKFNhI3R  5e1f2837d95637258ebc9ace    male  57
# 9  62adc5e962c20f22bf529d98  Ku6OCxxY  60ff34d0681649ea4e694114  female  33
#
#         race   education                                      variables_1  \
# ...

# %%
df.to_csv('pilot_belief.csv', index=True)

# %%
df.columns
# Out:
# Index(['ID', 'usertoken', 'prolificID', 'gender', 'age', 'race', 'education',
#        'variables_1', 'variables_2', 'variables_3', 'timerVal_1', 'timerVal_2',
#        'prior_belief_1', 'prior_uncertainty_1_L', 'prior_uncertainty_1_R',
#        'data_rho_1', 'data_CI_1_L', 'data_CI_1_R', 'post_belief_1',
#        'post_uncertainty_1_L', 'post_uncertainty_1_R', 'prior_belief_2',
#        'prior_uncertainty_2_L', 'prior_uncertainty_2_R', 'data_rho_2',
#        'data_CI_2_L', 'data_CI_2_R', 'post_belief_2', 'post_uncertainty_2_L',
#        'post_uncertainty_2_R', 'prior_belief_3', 'prior_uncertainty_3_L',
#        'prior_uncertainty_3_R', 'data_rho_3', 'data_CI_3_L', 'data_CI_3_R',
#        'post_belief_3', 'post_uncertainty_3_L', 'post_uncertainty_3_R',
#        'retro_1_prior', 'retro_1_post', 'retro_2_prior', 'retro_2_post',
#        'retro_3_prior', 'retro_3_post'],
#       dtype='object')

# %%
df[['age', 'timerVal_1', 'timerVal_2',
       'prior_belief_1', 'prior_uncertainty_1_L', 'prior_uncertainty_1_R',
       'data_rho_1', 'data_CI_1_L', 'data_CI_1_R', 'post_belief_1',
       'post_uncertainty_1_L', 'post_uncertainty_1_R', 'prior_belief_2',
       'prior_uncertainty_2_L', 'prior_uncertainty_2_R', 'data_rho_2',
       'data_CI_2_L', 'data_CI_2_R', 'post_belief_2', 'post_uncertainty_2_L',
       'post_uncertainty_2_R', 'prior_belief_3', 'prior_uncertainty_3_L',
       'prior_uncertainty_3_R', 'data_rho_3', 'data_CI_3_L', 'data_CI_3_R',
       'post_belief_3', 'post_uncertainty_3_L', 'post_uncertainty_3_R']] = df[['age', 'timerVal_1', 'timerVal_2',
       'prior_belief_1', 'prior_uncertainty_1_L', 'prior_uncertainty_1_R',
       'data_rho_1', 'data_CI_1_L', 'data_CI_1_R', 'post_belief_1',
       'post_uncertainty_1_L', 'post_uncertainty_1_R', 'prior_belief_2',
       'prior_uncertainty_2_L', 'prior_uncertainty_2_R', 'data_rho_2',
       'data_CI_2_L', 'data_CI_2_R', 'post_belief_2', 'post_uncertainty_2_L',
       'post_uncertainty_2_R', 'prior_belief_3', 'prior_uncertainty_3_L',
       'prior_uncertainty_3_R', 'data_rho_3', 'data_CI_3_L', 'data_CI_3_R',
       'post_belief_3', 'post_uncertainty_3_L', 'post_uncertainty_3_R']].apply(pd.to_numeric)

# %%
df['corr_diff_1'] = abs(df['data_rho_1'] - df['post_belief_1'])
df['corr_diff_2'] = abs(df['data_rho_2'] - df['post_belief_2'])
df['corr_diff_3'] = abs(df['data_rho_3'] - df['post_belief_3'])

# %%
df['pcorr_diff_1'] = abs(df['prior_belief_1'] - df['post_belief_1'])
df['pcorr_diff_2'] = abs(df['prior_belief_2'] - df['post_belief_2'])
df['pcorr_diff_3'] = abs(df['prior_belief_3'] - df['post_belief_3'])

# %%
df['corr_diff_1']
# Out:
# 0    1.144960
# 1    0.200610
# 2    0.283803
# 3    0.427010
# 4    0.074323
# 5    0.727747
# 6    1.206794
# 7    1.060555
# 8    0.277136
# 9    0.199587
# Name: corr_diff_1, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# fig = pplt.figure(suptitle="Correlation Difference")
# ax = fig.subplot(xlabel = 'corr diff')
# ax.plot(x= df['corr_diff_1'], y= 0.0, marker = 'o')
# plt.figure(figsize = (12,12))


corrplot = sns.scatterplot(x= df['corr_diff_1'], y= 0.0, marker = 'o', s = 120)
corrplot = sns.scatterplot(x= df['corr_diff_2'], y= 0.5, marker = 'o', s = 120)
corrplot = sns.scatterplot(x= df['corr_diff_3'], y= 1.0, marker = 'o', s = 120)
# corrplot.set(xlabel = 'Timer Value', ylabel = 'Correlation Difference')
corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('Correlation Difference', fontsize = 17)
corrplot.set_yticks([0.0, 0.5, 1.0])
corrplot.set_yticklabels(['', '1 min', '2 min'])
plt.savefig("correlation_diff.png")

# %%
corrplot = sns.scatterplot(x= df['pcorr_diff_1'], y= 0.0, marker = 'o', s = 120)
corrplot = sns.scatterplot(x= df['pcorr_diff_2'], y= 0.5, marker = 'o', s = 120)
corrplot = sns.scatterplot(x= df['pcorr_diff_3'], y= 1.0, marker = 'o', s = 120)
# corrplot.set(xlabel = 'Timer Value', ylabel = 'Correlation Difference')
corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('PP Correlation Difference', fontsize = 17)
corrplot.set_yticks([0.0, 0.5, 1.0])
corrplot.set_yticklabels(['0 min', '1 min', '2 min'])
# plt.savefig("pp_correlation_diff.png")
# Out:
# [Text(0, 0, ''), Text(0, 0, '1 min'), Text(0, 0, '2 min')]

# %%
plt.figure(figsize = (10,10))

priorplot = sns.scatterplot(x= df['prior_belief_1'], y= 0.0, marker = 'o', s = 120)
priorplot = sns.scatterplot(x= df['prior_belief_2'], y= 0.5, marker = 'o', s = 120)
priorplot = sns.scatterplot(x= df['prior_belief_1'], y= 1.0, marker = 'o', s = 120)

priorplot.set_ylabel('Variables', fontsize = 17)
priorplot.set_xlabel('Prior Beliefs', fontsize = 17)
priorplot.set_yticks([0.0, 0.5, 1.0])
priorplot.set_yticklabels(['Immigration Population x Crime', 'Hours on Social Media x Depression', 'Education x Income'], rotation = 90)
plt.savefig("prior_beliefs.png")

# %%
plt.figure(figsize = (10,10))

priorplot = sns.scatterplot(x= df['post_belief_1'], y= 0.0, marker = 'o', s = 120)
priorplot = sns.scatterplot(x= df['post_belief_2'], y= 0.5, marker = 'o', s = 120)
priorplot = sns.scatterplot(x= df['post_belief_1'], y= 1.0, marker = 'o', s = 120)

priorplot.set_ylabel('Variables', fontsize = 17)
priorplot.set_xlabel('Posterior Beliefs', fontsize = 17)
priorplot.set_yticks([0.0, 0.5, 1.0])
priorplot.set_yticklabels(['Immigration Population x Crime', 'Hours on Social Media x Depression', 'Education x Income'], rotation = 90)
plt.savefig("posterior_beliefs.png")

# %%
# Single subplot
import numpy as np
import proplot as pplt
state = np.random.RandomState(51423)
data = 2 * (state.rand(100, 5) - 0.5).cumsum(axis=0)
fig = pplt.figure(suptitle='Single subplot')
ax = fig.subplot(xlabel='x axis', ylabel='y axis')
ax.plot(data, lw=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-b1c69425b97c> in <module>
#       4 state = np.random.RandomState(51423)
#       5 data = 2 * (state.rand(100, 5) - 0.5).cumsum(axis=0)
# ----> 6 fig = pplt.figure(suptitle='Single subplot')
#       7 ax = fig.subplot(xlabel='x axis', ylabel='y axis')
#       8 ax.plot(data, lw=2)
#
# TypeError: 'module' object is not callable

# %%
abs(-0.88 - 0.45)
# Out:
# 1.33

# %%
####################################################### VERSION 2 #######################################################

# %%
################################## Version 2.0 ##################################

# %%
mycollection_v2_0 = mydb["confstudy_v2_0"]

# %%
docs_v2_0 = mycollection_v2_0.find()

docs_coll_v2_0 = {}
count = 1
for d in docs_v2_0:
    docs_coll_v2_0[count] = d
    count = count + 1

# %%
docs_coll_v2_0[37]
# Out:
# {'_id': ObjectId('62d0d1388b823201ce794315'),
#  'usertoken': 'oflDDyig',
#  'variables': [[['Immigrant population', 'Crime rate'], 'Countries']],
#  'timerArr': [],
#  'responses': [{'belief': '0.40055857661915883',
#    'uncertainty': ['-0.16849499169589505', '0.9696121449342128'],
#    'startTime': '1657852255029',
#    'endTime': '1657852267299',
#    'state': 'draw1',
#    'variables': [['Immigrant population', 'Crime rate'], 'Countries']},
#   {'startTime': '1657852267784',
#    'endTime': '1657852270597',
#    'dataShown': [{'x': '0.5524893294956349', 'y': '-0.9538646311269697'},
#     {'x': '0.8156250957715219', 'y': '-1.1833301417051258'},
#     {'x': '-1.030727847468825', 'y': '0.5526725355530463'},
#     {'x': '1.0740615336372126', 'y': '-0.6856888976127797'},
#     {'x': '0.39824532758889725', 'y': '-1.1785513139090356'},
#     {'x': '-0.4163038881366237', 'y': '-0.45909235540715376'},
#     {'x': '-0.5708196812414742', 'y': '-0.6096309749182345'},
# ...

# %%
############### writing the complete records to a text file ###############
with open("data_BP_v2_0.txt", 'w') as f: 
    f.write(str(docs_coll_v2_0[22]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_0[23]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_0[25]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_0[26]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_0[27]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_0[28]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_0[29]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_0[30]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_0[31]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_0[32]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_0[35]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_0[36]))
    f.write("\n\n\n")

# %%
############### json file for the records ###############
import json
docs_list_v2_0 = [str(docs_coll_v2_0[22]), str(docs_coll_v2_0[23]), str(docs_coll_v2_0[25]), str(docs_coll_v2_0[26]), str(docs_coll_v2_0[27]), 
                  str(docs_coll_v2_0[28]), str(docs_coll_v2_0[29]), str(docs_coll_v2_0[30]), str(docs_coll_v2_0[31]), str(docs_coll_v2_0[32]), 
                  str(docs_coll_v2_0[35]), str(docs_coll_v2_0[36])]

with open('data_pilot_v2_0.json', 'w') as fp:
    json.dump(docs_list_v2_0, fp)

# %%
############### creating a dataframe for the records  ###############
cols = ['ID', 'usertoken', 'prolificID', 'gender', 'age', 'race', 'education', 'variables', 'timerVal',
       'prior_belief', 'prior_uncertainty_L', 'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R', 'post_belief',
       'post_uncertainty_L', 'post_uncertainty_R', 'retro_prior', 'retro_post']

df_v2_0 = pd.DataFrame(columns=cols , index=range(12))

c = 0
for idx in range(22, 37):
    if idx == 24 or idx == 33 or idx == 34:
        continue
        
    df_v2_0.loc[c].ID = docs_coll_v2_0[idx]['_id']
    df_v2_0.loc[c].usertoken = docs_coll_v2_0[idx]['usertoken']
    df_v2_0.loc[c].prolificID = docs_coll_v2_0[idx]['prequestionnaire']['profID']
    df_v2_0.loc[c].gender = docs_coll_v2_0[idx]['prequestionnaire']['genderRadios']
    df_v2_0.loc[c].age = docs_coll_v2_0[idx]['prequestionnaire']['age']
    df_v2_0.loc[c].race = docs_coll_v2_0[idx]['prequestionnaire']['raceRadios']
    df_v2_0.loc[c].education = docs_coll_v2_0[idx]['prequestionnaire']['eduRadios']

    df_v2_0.loc[c].variables = docs_coll_v2_0[idx]['variables'][0]
    df_v2_0.loc[c].timerVal = 0

    df_v2_0.loc[c].prior_belief = docs_coll_v2_0[idx]['responses'][0]['belief']
    df_v2_0.loc[c].prior_uncertainty_L = docs_coll_v2_0[idx]['responses'][0]['uncertainty'][0]
    df_v2_0.loc[c].prior_uncertainty_R = docs_coll_v2_0[idx]['responses'][0]['uncertainty'][1]
    df_v2_0.loc[c].data_rho = docs_coll_v2_0[idx]['responses'][1]['rhoBoot']['pearsonr']
    df_v2_0.loc[c].data_CI_L = docs_coll_v2_0[idx]['responses'][1]['rhoBoot']['CI'][0]
    df_v2_0.loc[c].data_CI_R = docs_coll_v2_0[idx]['responses'][1]['rhoBoot']['CI'][1]
    df_v2_0.loc[c].post_belief = docs_coll_v2_0[idx]['responses'][2]['belief']
    df_v2_0.loc[c].post_uncertainty_L = docs_coll_v2_0[idx]['responses'][2]['uncertainty'][0]
    df_v2_0.loc[c].post_uncertainty_R = docs_coll_v2_0[idx]['responses'][2]['uncertainty'][1]

    df_v2_0.loc[c].retro_prior = docs_coll_v2_0[idx]['retroResponses'][0]['retroReasonVal_1']
    df_v2_0.loc[c].retro_post = docs_coll_v2_0[idx]['retroResponses'][0]['retroReasonVal_2']
    
    c = c+ 1

# %%
df_v2_0
# Out:
#                           ID usertoken                prolificID  gender age  \
# 0   62d0770a266fb717db8998af  uv6g3R8Y  60fdb78245d5256047920390  female  23
# 1   62d077b6266fb717db8998b3  Xj6Pf9Az  5dd9ad296ca7e7949fdc13ea  female  20
# 2   62d0784e266fb717db8998c1  EZwrYvA9  558833f7fdf99b3a56b47f38    male  27
# 3   62d078a2266fb717db8998c6  JkIhpEiR  5b60c3376a4e130001513128    male  32
# 4   62d078be266fb717db8998cc  xYWE2RXJ  5e1797da928b15062260e30e    male  71
# 5   62d0795b266fb717db8998d8  9nXo92Mb  5dcdd7bf324a3d0a6c24b608    male  25
# 6   62d0796e266fb717db8998db  l9iwRbfN  5fc54a4839204604d13affd5  female  42
# 7   62d07abc266fb717db8998e5  WOmef6Ms  5f6cefecb8137d13565d8c33  female  21
# 8   62d07ac6266fb717db8998e8  FW4MGXEv  614a8bf9dbbb5293fd3b63ab    male  19
# 9   62d07afd266fb717db8998ee  28vmuHjN  5e1882adfd7db4158998b5f0    male  32
# 10  62d07cc4266fb717db89990c  qDgc7rXr  6234ab6c48539b0da7787118  female  48
# ...

# %%
df_v2_0.to_csv('pilot_belief_v2_0.csv', index=True)

# %%
################################## Version 2.1 ##################################

# %%
mycollection_v2_1 = mydb["confstudy_v2_1"]

# %%
docs_v2_1 = mycollection_v2_1.find()

docs_coll_v2_1 = {}
count = 1
for d in docs_v2_1:
    docs_coll_v2_1[count] = d
    count = count + 1

# %%
docs_coll_v2_1[28]
# Out:
# {'_id': ObjectId('62d08605eba055cec4ce84c7'),
#  'usertoken': 'RNeBoM2I',
#  'variables': [[['Immigrant population', 'Crime rate'], 'Countries']],
#  'timerArr': [{'timerV': '1'}],
#  'responses': [{'belief': '0.4290135250909157',
#    'uncertainty': ['-0.14197294981816816', '1'],
#    'startTime': '1657833065420',
#    'endTime': '1657833072788',
#    'state': 'draw1',
#    'variables': [['Immigrant population', 'Crime rate'], 'Countries']},
#   {'startTime': '1657833073579',
#    'endTime': '1657833076755',
#    'dataShown': [{'x': '0.5925215852013428', 'y': '0.27997515475790213'},
#     {'x': '-2.0017427143021886', 'y': '2.0880884142923324'},
#     {'x': '1.3720086722519966', 'y': '-0.4773167334502753'},
#     {'x': '0.6761310093120355', 'y': '-1.5474370807525208'},
#     {'x': '-0.8550239323701894', 'y': '-0.6669480713147691'},
#     {'x': '0.5153122385573903', 'y': '0.6462531908138418'},
#     {'x': '0.5683806144099732', 'y': '-1.165643851872028'},
# ...

# %%
############### writing the complete records to a text file ###############
with open("data_BP_v2_1.txt", 'w') as f: 
    f.write(str(docs_coll_v2_1[12]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_1[14]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_1[15]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_1[16]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_1[17]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_1[19]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_1[21]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_1[23]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_1[25]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_1[26]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_1[28]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_1[29]))
    f.write("\n\n\n")

# %%
############### json file for the records ###############
import json
docs_list_v2_1 = [str(docs_coll_v2_1[12]), str(docs_coll_v2_1[14]), str(docs_coll_v2_1[15]), str(docs_coll_v2_1[16]), str(docs_coll_v2_1[17]), 
                  str(docs_coll_v2_1[19]), str(docs_coll_v2_1[21]), str(docs_coll_v2_1[23]), str(docs_coll_v2_1[25]), str(docs_coll_v2_1[26]), 
                  str(docs_coll_v2_1[28]), str(docs_coll_v2_1[29])]

with open('data_pilot_v2_1.json', 'w') as fp:
    json.dump(docs_list_v2_1, fp)

# %%
############### creating a dataframe for the records  ###############
cols = ['ID', 'usertoken', 'prolificID', 'gender', 'age', 'race', 'education', 'variables', 'timerVal',
       'prior_belief', 'prior_uncertainty_L', 'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R', 'post_belief',
       'post_uncertainty_L', 'post_uncertainty_R', 'retro_prior', 'retro_post']

df_v2_1 = pd.DataFrame(columns=cols , index=range(12))

c = 0
for idx in range(12, 30):
    if idx == 13 or idx == 18 or idx == 19 or idx == 20 or idx == 22 or idx == 24 or idx == 27:
        continue
        
    df_v2_1.loc[c].ID = docs_coll_v2_1[idx]['_id']
    df_v2_1.loc[c].usertoken = docs_coll_v2_1[idx]['usertoken']
    df_v2_1.loc[c].prolificID = docs_coll_v2_1[idx]['prequestionnaire']['profID']
    df_v2_1.loc[c].gender = docs_coll_v2_1[idx]['prequestionnaire']['genderRadios']
    df_v2_1.loc[c].age = docs_coll_v2_1[idx]['prequestionnaire']['age']
    df_v2_1.loc[c].race = docs_coll_v2_1[idx]['prequestionnaire']['raceRadios']
    df_v2_1.loc[c].education = docs_coll_v2_1[idx]['prequestionnaire']['eduRadios']

    df_v2_1.loc[c].variables = docs_coll_v2_1[idx]['variables'][0]
    df_v2_1.loc[c].timerVal = 1

    df_v2_1.loc[c].prior_belief = docs_coll_v2_1[idx]['responses'][0]['belief']
    df_v2_1.loc[c].prior_uncertainty_L = docs_coll_v2_1[idx]['responses'][0]['uncertainty'][0]
    df_v2_1.loc[c].prior_uncertainty_R = docs_coll_v2_1[idx]['responses'][0]['uncertainty'][1]
    df_v2_1.loc[c].data_rho = docs_coll_v2_1[idx]['responses'][1]['rhoBoot']['pearsonr']
    df_v2_1.loc[c].data_CI_L = docs_coll_v2_1[idx]['responses'][1]['rhoBoot']['CI'][0]
    df_v2_1.loc[c].data_CI_R = docs_coll_v2_1[idx]['responses'][1]['rhoBoot']['CI'][1]
    df_v2_1.loc[c].post_belief = docs_coll_v2_1[idx]['responses'][2]['belief']
    df_v2_1.loc[c].post_uncertainty_L = docs_coll_v2_1[idx]['responses'][2]['uncertainty'][0]
    df_v2_1.loc[c].post_uncertainty_R = docs_coll_v2_1[idx]['responses'][2]['uncertainty'][1]

    df_v2_1.loc[c].retro_prior = docs_coll_v2_1[idx]['retroResponses'][0]['retroReasonVal_1']
    df_v2_1.loc[c].retro_post = docs_coll_v2_1[idx]['retroResponses'][0]['retroReasonVal_2']
    
    c = c+ 1

##### Filling the missing row #####
df_v2_1.loc[11].ID = docs_coll_v2_1[19]['_id']
df_v2_1.loc[11].usertoken = docs_coll_v2_1[19]['usertoken']
df_v2_1.loc[11].prolificID = docs_coll_v2_1[19]['prequestionnaire']['profID']
df_v2_1.loc[11].gender = docs_coll_v2_1[19]['prequestionnaire']['genderRadios']
df_v2_1.loc[11].age = docs_coll_v2_1[19]['prequestionnaire']['age']
df_v2_1.loc[11].race = docs_coll_v2_1[19]['prequestionnaire']['raceRadios']
df_v2_1.loc[11].education = docs_coll_v2_1[19]['prequestionnaire']['eduRadios']

df_v2_1.loc[11].variables = docs_coll_v2_1[19]['variables'][0]
df_v2_1.loc[11].timerVal = 1

df_v2_1.loc[11].prior_belief = docs_coll_v2_1[19]['responses'][0]['belief']
df_v2_1.loc[11].prior_uncertainty_L = docs_coll_v2_1[19]['responses'][0]['uncertainty'][0]
df_v2_1.loc[11].prior_uncertainty_R = docs_coll_v2_1[19]['responses'][0]['uncertainty'][1]
df_v2_1.loc[11].data_rho = docs_coll_v2_1[19]['responses'][1]['rhoBoot']['pearsonr']
df_v2_1.loc[11].data_CI_L = docs_coll_v2_1[19]['responses'][1]['rhoBoot']['CI'][0]
df_v2_1.loc[11].data_CI_R = docs_coll_v2_1[19]['responses'][1]['rhoBoot']['CI'][1]
df_v2_1.loc[11].post_belief = docs_coll_v2_1[19]['responses'][2]['belief']
df_v2_1.loc[11].post_uncertainty_L = docs_coll_v2_1[19]['responses'][2]['uncertainty'][0]
df_v2_1.loc[11].post_uncertainty_R = docs_coll_v2_1[19]['responses'][2]['uncertainty'][1]

df_v2_1.loc[11].retro_prior = ""
df_v2_1.loc[11].retro_post = ""

# %%
df_v2_1
# Out:
#                           ID usertoken                prolificID  gender age  \
# 0   62d0797aeba055cec4ce844b  gZ7mP1Dh  558833f7fdf99b3a56b47f38    male  27
# 1   62d07ac4eba055cec4ce8458  wnrd08N0  61002399798bfe567e2c10b4  female  21
# 2   62d07b04eba055cec4ce845b  EqxLFnzf  5e6ef5fbf14d264ae2ef3867    male  32
# 3   62d07b7deba055cec4ce8461  CGrsB5Mq  6009a44e7fcfa0016fe05284    male  24
# 4   62d07ba3eba055cec4ce8467  xbBDHDY9  5f52682826475e5116d539be  female  26
# 5   62d07d1beba055cec4ce848c  8cw8t4BQ  5c5c75d6329ee20001083061    male  39
# 6   62d07d46eba055cec4ce8493  GPjGOL2w  60cf3c8ed9f0c2b149342756    male  40
# 7   62d07e42eba055cec4ce84a2  8kImZi2b  62aa2a096b59ca953807647c  female  18
# 8   62d07e60eba055cec4ce84a5  PyMy7pcF  611173900721df318b8151c7  female  20
# 9   62d08605eba055cec4ce84c7  RNeBoM2I  62cf613d0992f7414e5b390f    male  25
# 10  62d08938eba055cec4ce84d3  9TiWUiQ2  550bb70bfdf99b6853dab45e  female  30
# ...

# %%
df_v2_1.to_csv('pilot_belief_v2_1.csv', index=True)

# %%
################################## Version 2.2 ##################################

# %%
mycollection_v2_2 = mydb["confstudy_v2_2"]

# %%
docs_v2_2 = mycollection_v2_2.find()

docs_coll_v2_2 = {}
count = 1
for d in docs_v2_2:
    docs_coll_v2_2[count] = d
    count = count + 1

# %%
docs_coll_v2_2[19]
# Out:
# {'_id': ObjectId('62d08ee8c87eb7d9cf068c13'),
#  'usertoken': 'aFLty3Wv',
#  'variables': [[['Immigrant population', 'Crime rate'], 'Countries']],
#  'timerArr': [{'timerV': '10'}],
#  'responses': [{'belief': '0.01989284016273407',
#    'uncertainty': ['-0.25379893070062437', '0.29358461102609246'],
#    'startTime': '1657835555771',
#    'endTime': '1657835564564',
#    'state': 'draw1',
#    'variables': [['Immigrant population', 'Crime rate'], 'Countries']},
#   {'startTime': '1657835566181',
#    'endTime': '1657835578895',
#    'dataShown': [{'x': '-1.0864829917253653', 'y': '1.3812368141965095'},
#     {'x': '0.4051845930964147', 'y': '-0.8260733315785387'},
#     {'x': '0.8864503845803946', 'y': '-0.8137143924757002'},
#     {'x': '-2.198432154676719', 'y': '1.4585100884070197'},
#     {'x': '-0.8385120425665331', 'y': '0.7885022094601064'},
#     {'x': '-0.9204711766043387', 'y': '0.36064907960496595'},
#     {'x': '0.4707251117427977', 'y': '-0.4006707308560202'},
# ...

# %%
############### writing the complete records to a text file ###############
with open("data_BP_v2_2.txt", 'w') as f: 
    f.write(str(docs_coll_v2_2[6]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_2[7]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_2[8]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_2[9]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_2[11]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_2[12]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_2[13]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_2[14]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_2[15]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_2[16]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_2[17]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_2[18]))

# %%
############### json file for the records ###############
import json
docs_list_v2_2 = [str(docs_coll_v2_2[6]), str(docs_coll_v2_2[7]), str(docs_coll_v2_2[8]), str(docs_coll_v2_2[9]), 
                  str(docs_coll_v2_2[11]), str(docs_coll_v2_2[12]), str(docs_coll_v2_2[13]), str(docs_coll_v2_2[14]), str(docs_coll_v2_2[15]), 
                  str(docs_coll_v2_2[16]), str(docs_coll_v2_2[17]), str(docs_coll_v2_2[18])]

with open('data_pilot_v2_2.json', 'w') as fp:
    json.dump(docs_list_v2_2, fp)

# %%
############### creating a dataframe for the records  ###############
cols = ['ID', 'usertoken', 'prolificID', 'gender', 'age', 'race', 'education', 'variables', 'timerVal',
       'prior_belief', 'prior_uncertainty_L', 'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R', 'post_belief',
       'post_uncertainty_L', 'post_uncertainty_R', 'retro_prior', 'retro_post']

df_v2_2 = pd.DataFrame(columns=cols , index=range(12))

c = 0
for idx in range(6, 19):
    if idx == 10 or idx == 19:
        continue
        
    df_v2_2.loc[c].ID = docs_coll_v2_2[idx]['_id']
    df_v2_2.loc[c].usertoken = docs_coll_v2_2[idx]['usertoken']
    df_v2_2.loc[c].prolificID = docs_coll_v2_2[idx]['prequestionnaire']['profID']
    df_v2_2.loc[c].gender = docs_coll_v2_2[idx]['prequestionnaire']['genderRadios']
    df_v2_2.loc[c].age = docs_coll_v2_2[idx]['prequestionnaire']['age']
    df_v2_2.loc[c].race = docs_coll_v2_2[idx]['prequestionnaire']['raceRadios']
    df_v2_2.loc[c].education = docs_coll_v2_2[idx]['prequestionnaire']['eduRadios']

    df_v2_2.loc[c].variables = docs_coll_v2_2[idx]['variables'][0]
    df_v2_2.loc[c].timerVal = 10

    df_v2_2.loc[c].prior_belief = docs_coll_v2_2[idx]['responses'][0]['belief']
    df_v2_2.loc[c].prior_uncertainty_L = docs_coll_v2_2[idx]['responses'][0]['uncertainty'][0]
    df_v2_2.loc[c].prior_uncertainty_R = docs_coll_v2_2[idx]['responses'][0]['uncertainty'][1]
    df_v2_2.loc[c].data_rho = docs_coll_v2_2[idx]['responses'][1]['rhoBoot']['pearsonr']
    df_v2_2.loc[c].data_CI_L = docs_coll_v2_2[idx]['responses'][1]['rhoBoot']['CI'][0]
    df_v2_2.loc[c].data_CI_R = docs_coll_v2_2[idx]['responses'][1]['rhoBoot']['CI'][1]
    df_v2_2.loc[c].post_belief = docs_coll_v2_2[idx]['responses'][2]['belief']
    df_v2_2.loc[c].post_uncertainty_L = docs_coll_v2_2[idx]['responses'][2]['uncertainty'][0]
    df_v2_2.loc[c].post_uncertainty_R = docs_coll_v2_2[idx]['responses'][2]['uncertainty'][1]

    df_v2_2.loc[c].retro_prior = docs_coll_v2_2[idx]['retroResponses'][0]['retroReasonVal_1']
    df_v2_2.loc[c].retro_post = docs_coll_v2_2[idx]['retroResponses'][0]['retroReasonVal_2']
    
    c = c+ 1

# %%
df_v2_2
# Out:
#                           ID usertoken                prolificID  gender age  \
# 0   62d07b3fc87eb7d9cf068b95  ppPPTTuk  6091bd96d843a1deae56e0db    male  33
# 1   62d07c7cc87eb7d9cf068b9d  WYxLJqI9  6009a44e7fcfa0016fe05284    male  24
# 2   62d07e0ac87eb7d9cf068ba5  BUlOg834  5f126ad529b0711af00b920c  female  23
# 3   62d07f09c87eb7d9cf068bae  UhsKMV0d  61453aab38b584216eb590d9  female  20
# 4   62d0806fc87eb7d9cf068bbc  rIbtv8L3  609208393ca8c7f478b023fd   Other  23
# 5   62d08088c87eb7d9cf068bbf  rmX7BFyH  5eac2cc56665cc23af76e945  female  25
# 6   62d08210c87eb7d9cf068bd0  AZKd3s1H  62d00720bfd649aa9f5c1946    male  33
# 7   62d08395c87eb7d9cf068bd6  3lPBypVH  616a360e63a646b8ccb0ef98  female  36
# 8   62d0839fc87eb7d9cf068bd8  e9HlGMh4  60970d6a412fb3ec1ec6c1a0    male  30
# 9   62d083c6c87eb7d9cf068bde  0xJ71C3E  5eebe50fcb2f6a17f44ba705  female  19
# 10  62d0841ac87eb7d9cf068be2  OT63vt5g  569ac88daf9ad70006640a66    male  32
# ...

# %%
df_v2_2.to_csv('pilot_belief_v2_2.csv', index=True)

# %%
################################## Version 2.3 ##################################

# %%
mycollection_v2_3 = mydb["confstudy_v2_3"]

# %%
docs_v2_3 = mycollection_v2_3.find()

docs_coll_v2_3 = {}
count = 1
for d in docs_v2_3:
    docs_coll_v2_3[count] = d
    count = count + 1

# %%
docs_coll_v2_3[31]
# Out:
# {'_id': ObjectId('62d08f4eec7ee9d03493cda0'),
#  'usertoken': 'lMAJEDru',
#  'variables': [[['Immigrant population', 'Crime rate'], 'Countries']],
#  'timerArr': [{'timerV': '30'}],
#  'responses': [{'belief': '-0.20123627608930184',
#    'uncertainty': ['-0.32840446503100607', '-0.0740680871475976'],
#    'startTime': '1657835580487',
#    'endTime': '1657835601257',
#    'state': 'draw1',
#    'variables': [['Immigrant population', 'Crime rate'], 'Countries']},
#   {'startTime': '1657835601920',
#    'endTime': '1657835615460',
#    'dataShown': [{'x': '1.2188455285640827', 'y': '1.757165001680583'},
#     {'x': '-2.175097374023778', 'y': '-0.18732994500541605'},
#     {'x': '-0.26746615029032483', 'y': '0.7999398181097035'},
#     {'x': '-0.8107790201382069', 'y': '-0.8505964181293447'},
#     {'x': '1.296077788069849', 'y': '1.3155065373104193'},
#     {'x': '0.7029992315088476', 'y': '-0.03817931050525601'},
#     {'x': '-1.2100100981070545', 'y': '-1.9314204085059121'},
# ...

# %%
############### writing the complete records to a text file ###############
with open("data_BP_v2_3.txt", 'w') as f: 
    f.write(str(docs_coll_v2_3[15]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_3[17]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_3[18]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_3[19]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_3[20]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_3[23]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_3[24]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_3[25]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_3[26]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_3[30]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_3[31]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v2_3[32]))

# %%
############### json file for the records ###############
import json
docs_list_v2_3 = [str(docs_coll_v2_3[15]), str(docs_coll_v2_3[17]), str(docs_coll_v2_3[18]), str(docs_coll_v2_3[19]), 
                  str(docs_coll_v2_3[20]), str(docs_coll_v2_3[23]), str(docs_coll_v2_3[24]), str(docs_coll_v2_3[25]), str(docs_coll_v2_3[26]), 
                  str(docs_coll_v2_3[30]), str(docs_coll_v2_3[31]), str(docs_coll_v2_3[32])]

with open('data_pilot_v2_3.json', 'w') as fp:
    json.dump(docs_list_v2_3, fp)

# %%
############### creating a dataframe for the records  ###############
cols = ['ID', 'usertoken', 'prolificID', 'gender', 'age', 'race', 'education', 'variables', 'timerVal',
       'prior_belief', 'prior_uncertainty_L', 'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R', 'post_belief',
       'post_uncertainty_L', 'post_uncertainty_R', 'retro_prior', 'retro_post']

df_v2_3 = pd.DataFrame(columns=cols , index=range(12))

c = 0
for idx in range(15, 33):
    if idx == 16 or idx == 21 or idx == 22 or idx == 24 or idx == 27 or idx == 28 or idx == 29:
        continue
        
    df_v2_3.loc[c].ID = docs_coll_v2_3[idx]['_id']
    df_v2_3.loc[c].usertoken = docs_coll_v2_3[idx]['usertoken']
    df_v2_3.loc[c].prolificID = docs_coll_v2_3[idx]['prequestionnaire']['profID']
    df_v2_3.loc[c].gender = docs_coll_v2_3[idx]['prequestionnaire']['genderRadios']
    df_v2_3.loc[c].age = docs_coll_v2_3[idx]['prequestionnaire']['age']
    df_v2_3.loc[c].race = docs_coll_v2_3[idx]['prequestionnaire']['raceRadios']
    df_v2_3.loc[c].education = docs_coll_v2_3[idx]['prequestionnaire']['eduRadios']

    df_v2_3.loc[c].variables = docs_coll_v2_3[idx]['variables'][0]
    df_v2_3.loc[c].timerVal = 30

    df_v2_3.loc[c].prior_belief = docs_coll_v2_3[idx]['responses'][0]['belief']
    df_v2_3.loc[c].prior_uncertainty_L = docs_coll_v2_3[idx]['responses'][0]['uncertainty'][0]
    df_v2_3.loc[c].prior_uncertainty_R = docs_coll_v2_3[idx]['responses'][0]['uncertainty'][1]
    df_v2_3.loc[c].data_rho = docs_coll_v2_3[idx]['responses'][1]['rhoBoot']['pearsonr']
    df_v2_3.loc[c].data_CI_L = docs_coll_v2_3[idx]['responses'][1]['rhoBoot']['CI'][0]
    df_v2_3.loc[c].data_CI_R = docs_coll_v2_3[idx]['responses'][1]['rhoBoot']['CI'][1]
    df_v2_3.loc[c].post_belief = docs_coll_v2_3[idx]['responses'][2]['belief']
    df_v2_3.loc[c].post_uncertainty_L = docs_coll_v2_3[idx]['responses'][2]['uncertainty'][0]
    df_v2_3.loc[c].post_uncertainty_R = docs_coll_v2_3[idx]['responses'][2]['uncertainty'][1]

    df_v2_3.loc[c].retro_prior = docs_coll_v2_3[idx]['retroResponses'][0]['retroReasonVal_1']
    df_v2_3.loc[c].retro_post = docs_coll_v2_3[idx]['retroResponses'][0]['retroReasonVal_2']
    
    c = c+ 1

##### Filling the missing row #####
df_v2_3.loc[11].ID = docs_coll_v2_3[24]['_id']
df_v2_3.loc[11].usertoken = docs_coll_v2_3[24]['usertoken']
df_v2_3.loc[11].prolificID = docs_coll_v2_3[24]['prequestionnaire']['profID']
df_v2_3.loc[11].gender = docs_coll_v2_3[24]['prequestionnaire']['genderRadios']
df_v2_3.loc[11].age = docs_coll_v2_3[24]['prequestionnaire']['age']
df_v2_3.loc[11].race = docs_coll_v2_3[24]['prequestionnaire']['raceRadios']
df_v2_3.loc[11].education = docs_coll_v2_3[24]['prequestionnaire']['eduRadios']

df_v2_3.loc[11].variables = docs_coll_v2_3[24]['variables'][0]
df_v2_3.loc[11].timerVal = 30

df_v2_3.loc[11].prior_belief = docs_coll_v2_3[24]['responses'][0]['belief']
df_v2_3.loc[11].prior_uncertainty_L = docs_coll_v2_3[24]['responses'][0]['uncertainty'][0]
df_v2_3.loc[11].prior_uncertainty_R = docs_coll_v2_3[24]['responses'][0]['uncertainty'][1]
df_v2_3.loc[11].data_rho = docs_coll_v2_3[24]['responses'][1]['rhoBoot']['pearsonr']
df_v2_3.loc[11].data_CI_L = docs_coll_v2_3[24]['responses'][1]['rhoBoot']['CI'][0]
df_v2_3.loc[11].data_CI_R = docs_coll_v2_3[24]['responses'][1]['rhoBoot']['CI'][1]
df_v2_3.loc[11].post_belief = docs_coll_v2_3[24]['responses'][2]['belief']
df_v2_3.loc[11].post_uncertainty_L = docs_coll_v2_3[24]['responses'][2]['uncertainty'][0]
df_v2_3.loc[11].post_uncertainty_R = docs_coll_v2_3[24]['responses'][2]['uncertainty'][1]

df_v2_3.loc[11].retro_prior = ""
df_v2_3.loc[11].retro_post = ""

# %%
df_v2_3
# Out:
#                           ID usertoken                prolificID  gender age  \
# 0   62d07f7dec7ee9d03493cd23  wZuv8W16  6009a44e7fcfa0016fe05284    male  24
# 1   62d08412ec7ee9d03493cd2f  ufIMv5yx  6290eb32e9066b26774ba466    male  42
# 2   62d08557ec7ee9d03493cd37  fkxfMIxK  6090b3f525cbbdcb540e6bbd  female  27
# 3   62d0857fec7ee9d03493cd3a  hl1VaMXY  6165a8ee6dde7ff6f4b22e6f  female  32
# 4   62d08601ec7ee9d03493cd3f  QoP9tvnx  5cd3ff1ac99584000199dd15    male  36
# 5   62d0865dec7ee9d03493cd4c  llEVcZdU  5df180b59b92b1098c0d5818  female  37
# 6   62d0871aec7ee9d03493cd56  L2mnUyh6  5f63a30a09bd340c84c6688d  female  43
# 7   62d087b9ec7ee9d03493cd6a  tEZc7zX3  59f21fe8cc514a00011a66cf  female  47
# 8   62d08f3eec7ee9d03493cd9c  azL8zlJh  6286d3ac3a161dab706a695c  female  29
# 9   62d08f4eec7ee9d03493cda0  lMAJEDru  5ec44da606cb7931f04a35e9    male  56
# 10  62d095a4ec7ee9d03493cdb6  oTGXZ9DK  5e2e7d79acf5fe45b62f859a  female  33
# ...

# %%
df_v2_3.to_csv('pilot_belief_v2_3.csv', index=True)

# %%
################## Plots ##################

# %%
df_v2 = pd.DataFrame()

# %%
df_v2_s0 = pd.DataFrame()
df_v2_s1 = pd.DataFrame()
df_v2_s2 = pd.DataFrame()
df_v2_s3 = pd.DataFrame()

# %%
df_v2_0.columns
# Out:
# Index(['ID', 'usertoken', 'prolificID', 'gender', 'age', 'race', 'education',
#        'variables', 'timerVal', 'prior_belief', 'prior_uncertainty_L',
#        'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R',
#        'post_belief', 'post_uncertainty_L', 'post_uncertainty_R',
#        'retro_prior', 'retro_post'],
#       dtype='object')

# %%
df_v2_0.shape, df_v2_1.shape, df_v2_2.shape, df_v2_3.shape
# Out:
# ((12, 20), (12, 20), (12, 20), (12, 20))

# %%
df_v2_0[['age', 'prior_belief', 'prior_uncertainty_L',
    'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R',
    'post_belief', 'post_uncertainty_L', 'post_uncertainty_R']] = df_v2_0[['age', 'prior_belief', 'prior_uncertainty_L',
    'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R',
    'post_belief', 'post_uncertainty_L', 'post_uncertainty_R']].apply(pd.to_numeric)

df_v2_1[['age', 'prior_belief', 'prior_uncertainty_L',
    'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R',
    'post_belief', 'post_uncertainty_L', 'post_uncertainty_R']] = df_v2_1[['age', 'prior_belief', 'prior_uncertainty_L',
    'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R',
    'post_belief', 'post_uncertainty_L', 'post_uncertainty_R']].apply(pd.to_numeric)

df_v2_2[['age', 'prior_belief', 'prior_uncertainty_L',
    'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R',
    'post_belief', 'post_uncertainty_L', 'post_uncertainty_R']] = df_v2_2[['age', 'prior_belief', 'prior_uncertainty_L',
    'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R',
    'post_belief', 'post_uncertainty_L', 'post_uncertainty_R']].apply(pd.to_numeric)

df_v2_3[['age', 'prior_belief', 'prior_uncertainty_L',
    'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R',
    'post_belief', 'post_uncertainty_L', 'post_uncertainty_R']] = df_v2_3[['age', 'prior_belief', 'prior_uncertainty_L',
    'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R',
    'post_belief', 'post_uncertainty_L', 'post_uncertainty_R']].apply(pd.to_numeric)

# %%
df_v2['corr_diff_0'] = abs(df_v2_0['data_rho'] - df_v2_0['post_belief'])
df_v2['corr_diff_1'] = abs(df_v2_1['data_rho'] - df_v2_1['post_belief'])
df_v2['corr_diff_2'] = abs(df_v2_2['data_rho'] - df_v2_2['post_belief'])
df_v2['corr_diff_3'] = abs(df_v2_3['data_rho'] - df_v2_3['post_belief'])

# %%
df_v2_s0['corr_diff'] = abs(df_v2_0['data_rho'] - df_v2_0['post_belief'])
df_v2_s0['timer'] = 0.0

df_v2_s1['corr_diff'] = abs(df_v2_1['data_rho'] - df_v2_1['post_belief'])
df_v2_s1['timer'] = 1.0

df_v2_s2['corr_diff'] = abs(df_v2_2['data_rho'] - df_v2_2['post_belief'])
df_v2_s2['timer'] = 10.0

df_v2_s3['corr_diff'] = abs(df_v2_3['data_rho'] - df_v2_3['post_belief'])
df_v2_s3['timer'] = 30.0

# %%
df_v2_s = pd.concat([df_v2_s0, df_v2_s1, df_v2_s2, df_v2_s3], ignore_index = True)

# %%
df_v2_s_means = df_v2_s.groupby("timer")["corr_diff"].agg("mean").reset_index()

# %%
df_v2_s_means
# Out:
#    timer  corr_diff
# 0    0.0   0.455272
# 1    1.0   0.402068
# 2   10.0   0.533249
# 3   30.0   0.438963

# %%
# sns.set_theme(style = "whitegrid")

plt.figure(figsize = (13,13))

ax = sns.swarmplot(x = "timer", y = "corr_diff", s = 15, data = df_v2_s)
xlim = ax.get_xlim()
ylim = ax.get_ylim()

sns.scatterplot(x = "timer", y = "corr_diff", marker = 'X', s = 500, color = 'black', ax = ax, legend = False, data = df_v2_s_means)

ax.set_xlim(xlim)
ax.set_ylim(ylim)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (13,13))

corrplot = sns.scatterplot(x= df_v2['corr_diff_0'], y= 0.0, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_v2['corr_diff_1'], y= 0.5, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_v2['corr_diff_2'], y= 1.0, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_v2['corr_diff_3'], y= 1.5, marker = 'o', s = 200)
# corrplot.set(xlabel = 'Timer Value', ylabel = 'Correlation Difference')
corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('Correlation Difference [Posterior - Data]', fontsize = 17)
corrplot.set_yticks([0.0, 0.5, 1.0, 1.5])
corrplot.set_yticklabels(['0 min', '1 min', '10 min', '30 min'])
plt.savefig("correlation_diff_version2.png")

# %%
df_v2['pcorr_diff_0'] = abs(df_v2_0['prior_belief'] - df_v2_0['post_belief'])
df_v2['pcorr_diff_1'] = abs(df_v2_1['prior_belief'] - df_v2_1['post_belief'])
df_v2['pcorr_diff_2'] = abs(df_v2_2['prior_belief'] - df_v2_2['post_belief'])
df_v2['pcorr_diff_3'] = abs(df_v2_3['prior_belief'] - df_v2_3['post_belief'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (13,13))

corrplot = sns.scatterplot(x= df_v2['pcorr_diff_0'], y= 0.0, marker = 'o', s = 120)
corrplot = sns.scatterplot(x= df_v2['pcorr_diff_1'], y= 0.5, marker = 'o', s = 120)
corrplot = sns.scatterplot(x= df_v2['pcorr_diff_2'], y= 1.0, marker = 'o', s = 120)
corrplot = sns.scatterplot(x= df_v2['pcorr_diff_3'], y= 1.5, marker = 'o', s = 120)

corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('Correlation Difference [Posterior - Prior]', fontsize = 17)
corrplot.set_yticks([0.0, 0.5, 1.0, 1.5])
corrplot.set_yticklabels(['0 min', '1 min', '10 min', '30 min'])
plt.savefig("ppcorrelation_diff_version2.png")

# %%
###################### Version 3 ######################

# %%
mycollection_v3 = mydb["confstudy_v3"]

# %%
docs_v3 = mycollection_v3.find()

docs_coll_v3 = {}
count = 1
for d in docs_v3:
    docs_coll_v3[count] = d
    count = count + 1

# %%
docs_coll_v3[58]
# Out:
# {'_id': ObjectId('62eafa95d5b81381eecaf025'),
#  'usertoken': '5ARLxRll',
#  'variables': [[['Immigrant population', 'Crime rate'], 'Countries'],
#   [['Avg. hours on social media', 'Depression severity'], 'People']],
#  'timerArr': [{'timerV': '10'}],
#  'responses': [{'belief': '0.07590534943372496',
#    'uncertainty': ['0.020027303707820465', '0.13178339515962922'],
#    'startTime': '1659567005154',
#    'endTime': '1659567020136',
#    'state': 'prior',
#    'variables': [['Immigrant population', 'Crime rate'], 'Countries']},
#   {'startTime': '1659567020839',
#    'endTime': '1659567033504',
#    'dataShown': [{'x': '0.09939647682685929', 'y': '0.5487511627575403'},
#     {'x': '-0.542360159505448', 'y': '0.17356440569157675'},
#     {'x': '-0.9981495785867627', 'y': '1.1148177877839776'},
#     {'x': '1.9456951425444495', 'y': '-1.168957009356508'},
#     {'x': '0.9945733409554312', 'y': '-0.16189222823539884'},
#     {'x': '0.367843667134339', 'y': '0.2879202009339072'},
# ...

# %%
############### writing the complete records to a text file ###############
with open("data_BP_v3.txt", 'w') as f: 
    f.write(str(docs_coll_v3[58]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v3[59]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v3[61]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v3[63]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v3[64]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v3[66]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v3[67]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v3[69]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v3[71]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v3[73]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v3[74]))
    f.write("\n\n\n")
    f.write(str(docs_coll_v3[75]))

# %%
############### json file for the records ###############
import json
docs_list_v3 = [str(docs_coll_v3[58]), str(docs_coll_v3[59]), str(docs_coll_v3[61]), str(docs_coll_v3[63]), 
                  str(docs_coll_v3[64]), str(docs_coll_v3[66]), str(docs_coll_v3[67]), str(docs_coll_v3[69]), str(docs_coll_v3[71]), 
                  str(docs_coll_v3[73]), str(docs_coll_v3[74]), str(docs_coll_v3[75])]

with open('data_pilot_v3.json', 'w') as fp:
    json.dump(docs_list_v3, fp)

# %%
############### creating a dataframe for the records  ###############
cols = ['ID', 'usertoken', 'prolificID', 'gender', 'age', 'race', 'education', 'variables_1', 'variables_2', 'timerVal',
       'prior_belief_1', 'prior_uncertainty_1_L', 'prior_uncertainty_1_R', 'data_rho_1', 'data_CI_1_L', 'data_CI_1_R', 'post1_belief_1',
       'post1_uncertainty_1_L', 'post1_uncertainty_1_R', 'post2_belief_1', 'post2_uncertainty_1_L', 'post2_uncertainty_1_R', 
        'prior_belief_2', 'prior_uncertainty_2_L', 'prior_uncertainty_2_R', 'data_rho_2', 'data_CI_2_L', 'data_CI_2_R', 'post1_belief_2',
       'post1_uncertainty_2_L', 'post1_uncertainty_2_R', 'post2_belief_2', 'post2_uncertainty_2_L', 'post2_uncertainty_2_R', 
        'retro_1_prior', 'retro_1_post1', 'retro_1_post2', 'retro_2_prior', 'retro_2_post1', 'retro_2_post2']

df_v3 = pd.DataFrame(columns = cols , index = range(12))

c = 0
for idx in range(57, 76):
    if idx == 59 or idx == 61 or idx == 64 or idx == 67 or idx == 69 or idx == 71 or idx == 73:
        continue
        
    df_v3.loc[c].ID = docs_coll_v3[idx]['_id']
    df_v3.loc[c].usertoken = docs_coll_v3[idx]['usertoken']
    df_v3.loc[c].prolificID = docs_coll_v3[idx]['prequestionnaire']['profID']
    df_v3.loc[c].gender = docs_coll_v3[idx]['prequestionnaire']['genderRadios']
    df_v3.loc[c].age = docs_coll_v3[idx]['prequestionnaire']['age']
    df_v3.loc[c].race = docs_coll_v3[idx]['prequestionnaire']['raceRadios']
    df_v3.loc[c].education = docs_coll_v3[idx]['prequestionnaire']['eduRadios']

    df_v3.loc[c].variables_1 = docs_coll_v3[idx]['variables'][0]
    df_v3.loc[c].variables_2 = docs_coll_v3[idx]['variables'][1]
    df_v3.loc[c].timerVal = 10

    df_v3.loc[c].prior_belief_1 = docs_coll_v3[idx]['responses'][0]['belief']
    df_v3.loc[c].prior_uncertainty_1_L = docs_coll_v3[idx]['responses'][0]['uncertainty'][0]
    df_v3.loc[c].prior_uncertainty_1_R = docs_coll_v3[idx]['responses'][0]['uncertainty'][1]
    df_v3.loc[c].data_rho_1 = docs_coll_v3[idx]['responses'][1]['rhoBoot']['pearsonr']
    df_v3.loc[c].data_CI_1_L = docs_coll_v3[idx]['responses'][1]['rhoBoot']['CI'][0]
    df_v3.loc[c].data_CI_1_R = docs_coll_v3[idx]['responses'][1]['rhoBoot']['CI'][1]
    df_v3.loc[c].post1_belief_1 = docs_coll_v3[idx]['responses'][2]['belief']
    df_v3.loc[c].post1_uncertainty_1_L = docs_coll_v3[idx]['responses'][2]['uncertainty'][0]
    df_v3.loc[c].post1_uncertainty_1_R = docs_coll_v3[idx]['responses'][2]['uncertainty'][1]
    df_v3.loc[c].post2_belief_1 = docs_coll_v3[idx]['responses'][3]['belief']
    df_v3.loc[c].post2_uncertainty_1_L = docs_coll_v3[idx]['responses'][3]['uncertainty'][0]
    df_v3.loc[c].post2_uncertainty_1_R = docs_coll_v3[idx]['responses'][3]['uncertainty'][1]
    
    df_v3.loc[c].prior_belief_2 = docs_coll_v3[idx]['responses'][4]['belief']
    df_v3.loc[c].prior_uncertainty_2_L = docs_coll_v3[idx]['responses'][4]['uncertainty'][0]
    df_v3.loc[c].prior_uncertainty_2_R = docs_coll_v3[idx]['responses'][4]['uncertainty'][1]
    df_v3.loc[c].data_rho_2 = docs_coll_v3[idx]['responses'][5]['rhoBoot']['pearsonr']
    df_v3.loc[c].data_CI_2_L = docs_coll_v3[idx]['responses'][5]['rhoBoot']['CI'][0]
    df_v3.loc[c].data_CI_2_R = docs_coll_v3[idx]['responses'][5]['rhoBoot']['CI'][1]
    df_v3.loc[c].post1_belief_2 = docs_coll_v3[idx]['responses'][6]['belief']
    df_v3.loc[c].post1_uncertainty_2_L = docs_coll_v3[idx]['responses'][6]['uncertainty'][0]
    df_v3.loc[c].post1_uncertainty_2_R = docs_coll_v3[idx]['responses'][6]['uncertainty'][1]
    df_v3.loc[c].post2_belief_2 = docs_coll_v3[idx]['responses'][7]['belief']
    df_v3.loc[c].post2_uncertainty_2_L = docs_coll_v3[idx]['responses'][7]['uncertainty'][0]
    df_v3.loc[c].post2_uncertainty_2_R = docs_coll_v3[idx]['responses'][7]['uncertainty'][1]


    df_v3.loc[c].retro_1_prior = docs_coll_v3[idx]['retroResponses'][0]['retroReasonVal_1']
    df_v3.loc[c].retro_1_post1 = docs_coll_v3[idx]['retroResponses'][0]['retroReasonVal_2']
    df_v3.loc[c].retro_1_post2 = docs_coll_v3[idx]['retroResponses'][0]['retroReasonVal_3']
    df_v3.loc[c].retro_2_prior = docs_coll_v3[idx]['retroResponses'][0]['retroReasonVal_1']
    df_v3.loc[c].retro_2_post1 = docs_coll_v3[idx]['retroResponses'][0]['retroReasonVal_2']
    df_v3.loc[c].retro_2_post2 = docs_coll_v3[idx]['retroResponses'][0]['retroReasonVal_3']

    
    c = c+ 1

# %%
df_v3.columns
# Out:
# Index(['ID', 'usertoken', 'prolificID', 'gender', 'age', 'race', 'education',
#        'variables_1', 'variables_2', 'timerVal', 'prior_belief_1',
#        'prior_uncertainty_1_L', 'prior_uncertainty_1_R', 'data_rho_1',
#        'data_CI_1_L', 'data_CI_1_R', 'post1_belief_1', 'post1_uncertainty_1_L',
#        'post1_uncertainty_1_R', 'post2_belief_1', 'post2_uncertainty_1_L',
#        'post2_uncertainty_1_R', 'prior_belief_2', 'prior_uncertainty_2_L',
#        'prior_uncertainty_2_R', 'data_rho_2', 'data_CI_2_L', 'data_CI_2_R',
#        'post1_belief_2', 'post1_uncertainty_2_L', 'post1_uncertainty_2_R',
#        'post2_belief_2', 'post2_uncertainty_2_L', 'post2_uncertainty_2_R',
#        'retro_1_prior', 'retro_1_post1', 'retro_1_post2', 'retro_2_prior',
#        'retro_2_post1', 'retro_2_post2'],
#       dtype='object')

# %%
df_v3.to_csv('pilot_belief_v3.csv', index=True)

# %%
################## Plots ##################

# %%
df_v3 = pd.read_csv('pilot_belief_v3.csv')

# %%
df_v3[['age', 'prior_belief_1', 'prior_uncertainty_1_L', 'prior_uncertainty_1_R', 'data_rho_1',
       'data_CI_1_L', 'data_CI_1_R', 'post1_belief_1', 'post1_uncertainty_1_L',
       'post1_uncertainty_1_R', 'post2_belief_1', 'post2_uncertainty_1_L','post2_uncertainty_1_R', 'prior_belief_2', 'prior_uncertainty_2_L',
       'prior_uncertainty_2_R', 'data_rho_2', 'data_CI_2_L', 'data_CI_2_R','post1_belief_2', 'post1_uncertainty_2_L', 'post1_uncertainty_2_R',
       'post2_belief_2', 'post2_uncertainty_2_L', 'post2_uncertainty_2_R',]] = df_v3[['age', 'prior_belief_1',
       'prior_uncertainty_1_L', 'prior_uncertainty_1_R', 'data_rho_1', 'data_CI_1_L', 'data_CI_1_R', 'post1_belief_1', 'post1_uncertainty_1_L',
       'post1_uncertainty_1_R', 'post2_belief_1', 'post2_uncertainty_1_L', 'post2_uncertainty_1_R', 'prior_belief_2', 'prior_uncertainty_2_L',
       'prior_uncertainty_2_R', 'data_rho_2', 'data_CI_2_L', 'data_CI_2_R','post1_belief_2', 'post1_uncertainty_2_L', 'post1_uncertainty_2_R',
       'post2_belief_2', 'post2_uncertainty_2_L', 'post2_uncertainty_2_R',]].apply(pd.to_numeric)

# %%
df_v3_plot = pd.DataFrame()

# %%
df_v3_plot['corr_diff1_data_post1'] = abs(df_v3['data_rho_1'] - df_v3['post1_belief_1'])
df_v3_plot['corr_diff1_data_post2'] = abs(df_v3['data_rho_1'] - df_v3['post2_belief_1'])
df_v3_plot['corr_diff1_post1_post2'] = abs(df_v3['post1_belief_1'] - df_v3['post2_belief_1'])
df_v3_plot['corr_diff2_data_post1'] = abs(df_v3['data_rho_2'] - df_v3['post1_belief_2'])
df_v3_plot['corr_diff2_data_post2'] = abs(df_v3['data_rho_2'] - df_v3['post2_belief_2'])
df_v3_plot['corr_diff2_post1_post2'] = abs(df_v3['post1_belief_2'] - df_v3['post2_belief_2'])

df_v3_plot['corr_diff1_prior_post1'] = abs(df_v3['prior_belief_1'] - df_v3['post1_belief_1'])
df_v3_plot['corr_diff1_prior_post2'] = abs(df_v3['prior_belief_1'] - df_v3['post2_belief_1'])
df_v3_plot['corr_diff2_prior_post1'] = abs(df_v3['prior_belief_2'] - df_v3['post1_belief_1'])
df_v3_plot['corr_diff2_prior_post2'] = abs(df_v3['prior_belief_2'] - df_v3['post2_belief_1'])

# %%
df_v3_plot
# Out:
#     corr_diff1_data_post1  corr_diff1_data_post2  corr_diff1_post1_post2  \
# 0                0.003987               0.008155                0.004168
# 1                0.175178               0.030147                0.205324
# 2                0.005332               0.046857                0.052189
# 3                0.382621               1.325159                0.942538
# 4                0.421275               0.858828                0.437553
# 5                0.172412               0.172412                0.000000
# 6                0.583778               0.989358                1.573136
# 7                0.437243               0.530728                0.093485
# 8                0.260273               0.957118                1.217391
# 9                0.208608               0.130838                0.077769
# 10               0.191669               0.106092                0.085577
# 11               0.288162               0.734082                0.445920
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (13,13))

corrplot = sns.scatterplot(x= df_v3_plot['corr_diff1_data_post1'], y= 0.0, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_v3_plot['corr_diff1_data_post2'], y= 0.5, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_v3_plot['corr_diff1_post1_post2'], y= 1.0, marker = 'o', s = 200)
# corrplot = sns.scatterplot(x= df_v2['corr_diff_3'], y= 1.5, marker = 'o', s = 200)
# corrplot.set(xlabel = 'Timer Value', ylabel = 'Correlation Difference')
corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('Correlation Difference [Varaible: Immigrant Population x Crime Rate]', fontsize = 17)
corrplot.set_yticks([0.0, 0.5, 1.0])
corrplot.set_yticklabels(['data-post1', 'data-post2', 'post1-post2'])
plt.savefig("correlation_diff1_version3.png")

# %%
plt.figure(figsize = (13,13))

corrplot = sns.scatterplot(x= df_v3_plot['corr_diff2_data_post1'], y= 0.0, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_v3_plot['corr_diff2_data_post2'], y= 0.5, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_v3_plot['corr_diff2_post1_post2'], y= 1.0, marker = 'o', s = 200)
# corrplot = sns.scatterplot(x= df_v2['corr_diff_3'], y= 1.5, marker = 'o', s = 200)
# corrplot.set(xlabel = 'Timer Value', ylabel = 'Correlation Difference')
corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('Correlation Difference [Varaible: Social Media Hourse x Depression Rate]', fontsize = 17)
corrplot.set_yticks([0.0, 0.5, 1.0])
corrplot.set_yticklabels(['data-post1', 'data-post2', 'post1-post2'])
plt.savefig("correlation_diff2_version3.png")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (5,5))

scatterplot1 = sns.scatterplot(x= df_v3_plot['corr_diff1_data_post1'], y= df_v3_plot['corr_diff1_data_post2'], marker = 'o', s = 200)
scatterplot1.set_ylabel('Posterior 2', fontsize = 17)
scatterplot1.set_xlabel('Posterior 1', fontsize = 17)
scatterplot1.set_title('Immigrant Population x Crime Rate', fontsize = 17)
# Out:
# Text(0.5, 1.0, 'Immigrant Population x Crime Rate')

# %%
plt.figure(figsize = (5,5))

scatterplot1 = sns.scatterplot(x= df_v3_plot['corr_diff2_data_post1'], y= df_v3_plot['corr_diff2_data_post2'], marker = 'o', s = 200)
scatterplot1.set_ylabel('Posterior 2', fontsize = 17)
scatterplot1.set_xlabel('Posterior 1', fontsize = 17)
scatterplot1.set_title('Social Media Hours x Depression Rate', fontsize = 17)
# Out:
# Text(0.5, 1.0, 'Social Media Hours x Depression Rate')

# %%
plt.figure(figsize = (5,5))

scatterplot1 = sns.scatterplot(x= df_v3_plot['corr_diff1_prior_post1'], y= df_v3_plot['corr_diff1_prior_post2'], marker = 'o', s = 200)
scatterplot1.set_ylabel('Prior - Posterior 2', fontsize = 17)
scatterplot1.set_xlabel('Prior - Posterior 1', fontsize = 17)
scatterplot1.set_title('Immigrant Population x Crime Rate', fontsize = 17)
# Out:
# Text(0.5, 1.0, 'Immigrant Population x Crime Rate')

# %%
plt.figure(figsize = (10,10))

corrplot = sns.scatterplot(x= df_v3_plot['corr_diff1_prior_post1'], y= 0.0, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_v3_plot['corr_diff1_prior_post2'], y= 0.5, marker = 'o', s = 200)
corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('Correlation Difference [Varaible: Immigrant Population x Crime Rate]', fontsize = 17)
corrplot.set_yticks([0.0, 0.5])
corrplot.set_yticklabels(['prior-post1', 'prior-post2'])
# plt.savefig("correlation_diff1_version3.png")
# Out:
# [Text(0, 0, 'prior-post1'), Text(0, 0, 'prior-post2')]

# %%
plt.figure(figsize = (10,10))

corrplot = sns.scatterplot(x= df_v3_plot['corr_diff2_prior_post1'], y= 0.0, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_v3_plot['corr_diff2_prior_post2'], y= 0.5, marker = 'o', s = 200)
corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('Correlation Difference [Varaible: Immigrant Population x Crime Rate]', fontsize = 17)
corrplot.set_yticks([0.0, 0.5])
corrplot.set_yticklabels(['prior-post1', 'prior-post2'])
# Out:
# [Text(0, 0, 'prior-post1'), Text(0, 0, 'prior-post2')]

# %%
########### Final Study #################

# %%
mycollection_vfin = mydb["confstudy_vfins"]

# %%
docs_vfin = mycollection_vfin.find()

docs_coll_vfin = {}
count = 1
for d in docs_vfin:
    docs_coll_vfin[count] = d
    count = count + 1

# %%
docs_coll_vfin[171]
# Out:
# {'_id': ObjectId('62fa9e3d930ab57fc9fe18f0'),
#  'usertoken': 'S9KjDKe3',
#  'variables': [[['Years of education', 'Income'], 'People'],
#   [['Avg. hours on social media', 'Depression severity'], 'People'],
#   [['Immigrant population', 'Crime rate'], 'Countries']],
#  'timerArr': [{'timerV': '5'}],
#  'responses': [{'belief': '0.24588697198279652',
#    'uncertainty': ['-0.508226056034407', '1'],
#    'startTime': '1660592026521',
#    'endTime': '1660592042699',
#    'state': 'prior',
#    'variables': [['Years of education', 'Income'], 'People']},
#   {'startTime': '1660592042920',
#    'endTime': '1660592048604',
#    'dataShown': [{'x': '0.3400156807543773', 'y': '1.3375212276161383'},
#     {'x': '-0.0222000132916301', 'y': '-0.003352825544418875'},
#     {'x': '0.24768852642545322', 'y': '-0.4457719392832876'},
#     {'x': '-0.5428939827274153', 'y': '1.1600449115892981'},
#     {'x': '0.5408754040796964', 'y': '-0.6317030286202426'},
# ...

# %%
b_id = open("bad_ids.txt", "w")

c = 0
id_list = ['62acb8e852416f340637c4cc', '5f8f0ae15fe9e60fbbbaead9', '60ea823910936e7bff37d86b', '6056962634a5230dacdb63fc', '5f0395a63963d05bc235abdb',
           '5fe218efbf7c82d3e44ada5d', '6080506f48d21d24010d64aa', '607897a566b792397d974201', '5c745295821a97001763fb1b']
for idx in range(15, 170):
    if idx == 22 or idx == 49 or idx == 75 or idx == 164:
        continue
        
    if docs_coll_vfin[idx]['prequestionnaire']['profID'] in id_list:
        print(docs_coll_vfin[idx])
        print("\n")
        print(idx, '--------',docs_coll_vfin[idx]['prequestionnaire']['profID'])
        print("\n\n\n")
        
    
    c = c+ 1

# %%
############### json file for the records ###############
import json
docs_list_vfin = [str(docs_coll_vfin[15]), str(docs_coll_vfin[18]), str(docs_coll_vfin[19]), str(docs_coll_vfin[21]), str(docs_coll_vfin[25]),
                  str(docs_coll_vfin[26]), str(docs_coll_vfin[28]), str(docs_coll_vfin[30]), str(docs_coll_vfin[32]), str(docs_coll_vfin[33]), 
                  str(docs_coll_vfin[34]), str(docs_coll_vfin[35]), str(docs_coll_vfin[38]), str(docs_coll_vfin[39]), str(docs_coll_vfin[40]), 
                str(docs_coll_vfin[41]), str(docs_coll_vfin[43]), str(docs_coll_vfin[46]), str(docs_coll_vfin[48]), str(docs_coll_vfin[53]),
               str(docs_coll_vfin[54]), str(docs_coll_vfin[55]), str(docs_coll_vfin[56]), str(docs_coll_vfin[57]), str(docs_coll_vfin[58]),
                  str(docs_coll_vfin[59]), str(docs_coll_vfin[60]), str(docs_coll_vfin[61]), str(docs_coll_vfin[65]), str(docs_coll_vfin[66]), 
                  str(docs_coll_vfin[67]), str(docs_coll_vfin[69]), str(docs_coll_vfin[72]), str(docs_coll_vfin[73]), str(docs_coll_vfin[74]), 
                str(docs_coll_vfin[76]), str(docs_coll_vfin[77]), str(docs_coll_vfin[79]), str(docs_coll_vfin[80]), str(docs_coll_vfin[81]),
               str(docs_coll_vfin[82]), str(docs_coll_vfin[83]), str(docs_coll_vfin[84]), str(docs_coll_vfin[86]), str(docs_coll_vfin[88]),
                  str(docs_coll_vfin[89]), str(docs_coll_vfin[90]), str(docs_coll_vfin[91]), str(docs_coll_vfin[93]), str(docs_coll_vfin[95]), 
                  str(docs_coll_vfin[96]), str(docs_coll_vfin[98]), str(docs_coll_vfin[99]), str(docs_coll_vfin[100]), str(docs_coll_vfin[104]), 
                str(docs_coll_vfin[105]), str(docs_coll_vfin[108]), str(docs_coll_vfin[110]), str(docs_coll_vfin[112]), str(docs_coll_vfin[115]),
               str(docs_coll_vfin[116]), str(docs_coll_vfin[117]), str(docs_coll_vfin[118]), str(docs_coll_vfin[121]), str(docs_coll_vfin[122]),
                  str(docs_coll_vfin[123]), str(docs_coll_vfin[126]), str(docs_coll_vfin[129]), str(docs_coll_vfin[130]), str(docs_coll_vfin[136]), 
                  str(docs_coll_vfin[137]), str(docs_coll_vfin[138]), str(docs_coll_vfin[139]), str(docs_coll_vfin[140]), str(docs_coll_vfin[142]), 
                str(docs_coll_vfin[143]), str(docs_coll_vfin[144]), str(docs_coll_vfin[145]), str(docs_coll_vfin[146]), str(docs_coll_vfin[147]),
               str(docs_coll_vfin[151]), str(docs_coll_vfin[153]), str(docs_coll_vfin[154]), str(docs_coll_vfin[156]), str(docs_coll_vfin[158]),
                  str(docs_coll_vfin[160]), str(docs_coll_vfin[162]), str(docs_coll_vfin[163]), str(docs_coll_vfin[165]), str(docs_coll_vfin[167]), 
                  str(docs_coll_vfin[168]), str(docs_coll_vfin[169]), str(docs_coll_vfin[171]), str(docs_coll_vfin[172]), str(docs_coll_vfin[173]), 
                  str(docs_coll_vfin[174]), str(docs_coll_vfin[175]), str(docs_coll_vfin[178]), str(docs_coll_vfin[179]), str(docs_coll_vfin[180]), 
                  str(docs_coll_vfin[181]), str(docs_coll_vfin[182])]

with open('data_pilot_vfin.json', 'w') as fp:
    json.dump(docs_list_vfin, fp)

# %%
############### creating a dataframe for the records  ###############
cols = ['ID', 'usertoken', 'prolificID', 'gender', 'age', 'race', 'education', 'variables', 'timerVal',
       'prior_belief', 'prior_uncertainty_L', 'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R', 'post1_belief',
       'post1_uncertainty_L', 'post1_uncertainty_R', 'post2_belief', 'post2_uncertainty_L', 'post2_uncertainty_R', 
        'retro_prior', 'retro_post1', 'retro_post2', 'likert', 'survey']

df_vfin = pd.DataFrame(columns = cols , index = range(306))

c = 0
ig_list = [16, 17, 20, 22, 23, 24, 27, 29, 31, 36, 37, 42, 44, 45, 47, 49, 50, 51, 52, 62, 63, 64, 68, 70, 71, 75, 78, 85, 87, 92, 94, 97, 101,
           102, 103, 106, 107, 109, 111, 113, 114, 119, 120, 124, 125, 127, 128, 131, 132, 133, 134, 135, 141, 148, 149, 150, 152, 155, 157, 
           159, 161, 164, 166, 170, 176, 177]
for idx in range(15, 183):
    
    if idx in ig_list:
        continue
    
#     print(idx)
        
    df_vfin.loc[c].ID = docs_coll_vfin[idx]['_id']
    df_vfin.loc[c].usertoken = docs_coll_vfin[idx]['usertoken']
    df_vfin.loc[c].prolificID = docs_coll_vfin[idx]['prequestionnaire']['profID']
    df_vfin.loc[c].gender = docs_coll_vfin[idx]['prequestionnaire']['genderRadios']
    df_vfin.loc[c].age = docs_coll_vfin[idx]['prequestionnaire']['age']
    df_vfin.loc[c].race = docs_coll_vfin[idx]['prequestionnaire']['raceRadios']
    df_vfin.loc[c].education = docs_coll_vfin[idx]['prequestionnaire']['eduRadios']

    df_vfin.loc[c].variables = docs_coll_vfin[idx]['variables'][0][0]
    df_vfin.loc[c].timerVal = 5

    df_vfin.loc[c].prior_belief = docs_coll_vfin[idx]['responses'][0]['belief']
    df_vfin.loc[c].prior_uncertainty_L = docs_coll_vfin[idx]['responses'][0]['uncertainty'][0]
    df_vfin.loc[c].prior_uncertainty_R = docs_coll_vfin[idx]['responses'][0]['uncertainty'][1]
    df_vfin.loc[c].data_rho = docs_coll_vfin[idx]['responses'][1]['rhoBoot']['pearsonr']
    df_vfin.loc[c].data_CI_L = docs_coll_vfin[idx]['responses'][1]['rhoBoot']['CI'][0]
    df_vfin.loc[c].data_CI_R = docs_coll_vfin[idx]['responses'][1]['rhoBoot']['CI'][1]
    df_vfin.loc[c].post1_belief = docs_coll_vfin[idx]['responses'][2]['belief']
    df_vfin.loc[c].post1_uncertainty_L = docs_coll_vfin[idx]['responses'][2]['uncertainty'][0]
    df_vfin.loc[c].post1_uncertainty_R = docs_coll_vfin[idx]['responses'][2]['uncertainty'][1]
    df_vfin.loc[c].post2_belief = docs_coll_vfin[idx]['responses'][3]['belief']
    df_vfin.loc[c].post2_uncertainty_L = docs_coll_vfin[idx]['responses'][3]['uncertainty'][0]
    df_vfin.loc[c].post2_uncertainty_R = docs_coll_vfin[idx]['responses'][3]['uncertainty'][1]
    df_vfin.loc[c].retro_prior = docs_coll_vfin[idx]['retroResponses'][0]['retroReasonVal_1']
    df_vfin.loc[c].retro_post1 = docs_coll_vfin[idx]['retroResponses'][0]['retroReasonVal_2']
    df_vfin.loc[c].retro_post2 = docs_coll_vfin[idx]['retroResponses'][0]['retroReasonVal_3']
    df_vfin.loc[c].likert = docs_coll_vfin[idx]['retroResponses'][0]['likert']
    df_vfin.loc[c].survey = docs_coll_vfin[idx]['survey']['freeform']


    #####################################################################################################################
    c = c+ 1
    
    df_vfin.loc[c].ID = docs_coll_vfin[idx]['_id']
    df_vfin.loc[c].usertoken = docs_coll_vfin[idx]['usertoken']
    df_vfin.loc[c].prolificID = docs_coll_vfin[idx]['prequestionnaire']['profID']
    df_vfin.loc[c].gender = docs_coll_vfin[idx]['prequestionnaire']['genderRadios']
    df_vfin.loc[c].age = docs_coll_vfin[idx]['prequestionnaire']['age']
    df_vfin.loc[c].race = docs_coll_vfin[idx]['prequestionnaire']['raceRadios']
    df_vfin.loc[c].education = docs_coll_vfin[idx]['prequestionnaire']['eduRadios']

    df_vfin.loc[c].variables = docs_coll_vfin[idx]['variables'][1][0]
    df_vfin.loc[c].timerVal = 5
    
    df_vfin.loc[c].prior_belief = docs_coll_vfin[idx]['responses'][4]['belief']
    df_vfin.loc[c].prior_uncertainty_L = docs_coll_vfin[idx]['responses'][4]['uncertainty'][0]
    df_vfin.loc[c].prior_uncertainty_R = docs_coll_vfin[idx]['responses'][4]['uncertainty'][1]
    df_vfin.loc[c].data_rho = docs_coll_vfin[idx]['responses'][5]['rhoBoot']['pearsonr']
    df_vfin.loc[c].data_CI_L = docs_coll_vfin[idx]['responses'][5]['rhoBoot']['CI'][0]
    df_vfin.loc[c].data_CI_R = docs_coll_vfin[idx]['responses'][5]['rhoBoot']['CI'][1]
    df_vfin.loc[c].post1_belief = docs_coll_vfin[idx]['responses'][6]['belief']
    df_vfin.loc[c].post1_uncertainty_L = docs_coll_vfin[idx]['responses'][6]['uncertainty'][0]
    df_vfin.loc[c].post1_uncertainty_R = docs_coll_vfin[idx]['responses'][6]['uncertainty'][1]
    df_vfin.loc[c].post2_belief = docs_coll_vfin[idx]['responses'][7]['belief']
    df_vfin.loc[c].post2_uncertainty_L = docs_coll_vfin[idx]['responses'][7]['uncertainty'][0]
    df_vfin.loc[c].post2_uncertainty_R = docs_coll_vfin[idx]['responses'][7]['uncertainty'][1]
    df_vfin.loc[c].retro_prior = docs_coll_vfin[idx]['retroResponses'][1]['retroReasonVal_1']
    df_vfin.loc[c].retro_post1 = docs_coll_vfin[idx]['retroResponses'][1]['retroReasonVal_2']
    df_vfin.loc[c].retro_post2 = docs_coll_vfin[idx]['retroResponses'][1]['retroReasonVal_3']
    df_vfin.loc[c].likert = docs_coll_vfin[idx]['retroResponses'][1]['likert']
    df_vfin.loc[c].survey = docs_coll_vfin[idx]['survey']['freeform']
    
    #####################################################################################################################
    c = c+ 1
    
    df_vfin.loc[c].ID = docs_coll_vfin[idx]['_id']
    df_vfin.loc[c].usertoken = docs_coll_vfin[idx]['usertoken']
    df_vfin.loc[c].prolificID = docs_coll_vfin[idx]['prequestionnaire']['profID']
    df_vfin.loc[c].gender = docs_coll_vfin[idx]['prequestionnaire']['genderRadios']
    df_vfin.loc[c].age = docs_coll_vfin[idx]['prequestionnaire']['age']
    df_vfin.loc[c].race = docs_coll_vfin[idx]['prequestionnaire']['raceRadios']
    df_vfin.loc[c].education = docs_coll_vfin[idx]['prequestionnaire']['eduRadios']

    df_vfin.loc[c].variables = docs_coll_vfin[idx]['variables'][2][0]
    df_vfin.loc[c].timerVal = 5
    
    df_vfin.loc[c].prior_belief = docs_coll_vfin[idx]['responses'][8]['belief']
    df_vfin.loc[c].prior_uncertainty_L = docs_coll_vfin[idx]['responses'][8]['uncertainty'][0]
    df_vfin.loc[c].prior_uncertainty_R = docs_coll_vfin[idx]['responses'][8]['uncertainty'][1]
    df_vfin.loc[c].data_rho = docs_coll_vfin[idx]['responses'][9]['rhoBoot']['pearsonr']
    df_vfin.loc[c].data_CI_L = docs_coll_vfin[idx]['responses'][9]['rhoBoot']['CI'][0]
    df_vfin.loc[c].data_CI_R = docs_coll_vfin[idx]['responses'][9]['rhoBoot']['CI'][1]
    df_vfin.loc[c].post1_belief = docs_coll_vfin[idx]['responses'][10]['belief']
    df_vfin.loc[c].post1_uncertainty_L = docs_coll_vfin[idx]['responses'][10]['uncertainty'][0]
    df_vfin.loc[c].post1_uncertainty_R = docs_coll_vfin[idx]['responses'][10]['uncertainty'][1]
    df_vfin.loc[c].post2_belief = docs_coll_vfin[idx]['responses'][11]['belief']
    df_vfin.loc[c].post2_uncertainty_L = docs_coll_vfin[idx]['responses'][11]['uncertainty'][0]
    df_vfin.loc[c].post2_uncertainty_R = docs_coll_vfin[idx]['responses'][11]['uncertainty'][1]
    df_vfin.loc[c].retro_prior = docs_coll_vfin[idx]['retroResponses'][2]['retroReasonVal_1']
    df_vfin.loc[c].retro_post1 = docs_coll_vfin[idx]['retroResponses'][2]['retroReasonVal_2']
    df_vfin.loc[c].retro_post2 = docs_coll_vfin[idx]['retroResponses'][2]['retroReasonVal_3']
    df_vfin.loc[c].likert = docs_coll_vfin[idx]['retroResponses'][2]['likert']
    df_vfin.loc[c].survey = docs_coll_vfin[idx]['survey']['freeform']
    
    c = c+ 1

print(c)
# Out:
# 306

# %%
df_vfin
# Out:
#                            ID usertoken                prolificID  gender age  \
# 0    62f67ae0fc70763173e81fc2  Swh7B1VF  60ca3935fb64d56e11014643  female  23
# 1    62f67ae0fc70763173e81fc2  Swh7B1VF  60ca3935fb64d56e11014643  female  23
# 2    62f67ae0fc70763173e81fc2  Swh7B1VF  60ca3935fb64d56e11014643  female  23
# 3    62f67f44fc70763173e81fdc  OwNbjsPH  5af9fab60a7ecb00011820b8  female  29
# 4    62f67f44fc70763173e81fdc  OwNbjsPH  5af9fab60a7ecb00011820b8  female  29
# ..                        ...       ...                       ...     ...  ..
# 301  62faa8ab930ab57fc9fe19a0  iTVlm8Ep  5ae5374253072800018d5c69    male  31
# 302  62faa8ab930ab57fc9fe19a0  iTVlm8Ep  5ae5374253072800018d5c69    male  31
# 303  62fabb0c930ab57fc9fe19fb  vx2CYiXG  62f31911f6572d09a0e47369    male  21
# 304  62fabb0c930ab57fc9fe19fb  vx2CYiXG  62f31911f6572d09a0e47369    male  21
# 305  62fabb0c930ab57fc9fe19fb  vx2CYiXG  62f31911f6572d09a0e47369    male  21
#
# ...

# %%
df_vfin.to_csv('pilot_belief_vfin.csv', index=True)

# %%
############### creating a BIG dataframe for the records  ###############
cols = ['ID', 'usertoken', 'prolificID', 'gender', 'age', 'race', 'education', 'variables', 'timerVal',
       'prior_belief', 'prior_uncertainty_L', 'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R', 'post_belief',
       'post_uncertainty_L', 'post_uncertainty_R', 'retro_prior', 'retro_post1', 'retro_post2', 'tetris_location', 'likert', 'survey']

df_vfin = pd.DataFrame(columns = cols , index = range(612))

c = 0
ig_list = [16, 17, 20, 22, 23, 24, 27, 29, 31, 36, 37, 42, 44, 45, 47, 49, 50, 51, 52, 62, 63, 64, 68, 70, 71, 75, 78, 85, 87, 92, 94, 97, 101,
           102, 103, 106, 107, 109, 111, 113, 114, 119, 120, 124, 125, 127, 128, 131, 132, 133, 134, 135, 141, 148, 149, 150, 152, 155, 157, 
           159, 161, 164, 166, 170, 176, 177]
for idx in range(15, 183):
    
    if idx in ig_list:
        continue
            
    df_vfin.loc[c].ID = docs_coll_vfin[idx]['_id']
    df_vfin.loc[c].usertoken = docs_coll_vfin[idx]['usertoken']
    df_vfin.loc[c].prolificID = docs_coll_vfin[idx]['prequestionnaire']['profID']
    df_vfin.loc[c].gender = docs_coll_vfin[idx]['prequestionnaire']['genderRadios']
    df_vfin.loc[c].age = docs_coll_vfin[idx]['prequestionnaire']['age']
    df_vfin.loc[c].race = docs_coll_vfin[idx]['prequestionnaire']['raceRadios']
    df_vfin.loc[c].education = docs_coll_vfin[idx]['prequestionnaire']['eduRadios']
    df_vfin.loc[c].variables = docs_coll_vfin[idx]['variables'][0][0]
    df_vfin.loc[c].timerVal = 0
    df_vfin.loc[c].prior_belief = docs_coll_vfin[idx]['responses'][0]['belief']
    df_vfin.loc[c].prior_uncertainty_L = docs_coll_vfin[idx]['responses'][0]['uncertainty'][0]
    df_vfin.loc[c].prior_uncertainty_R = docs_coll_vfin[idx]['responses'][0]['uncertainty'][1]
    df_vfin.loc[c].data_rho = docs_coll_vfin[idx]['responses'][1]['rhoBoot']['pearsonr']
    df_vfin.loc[c].data_CI_L = docs_coll_vfin[idx]['responses'][1]['rhoBoot']['CI'][0]
    df_vfin.loc[c].data_CI_R = docs_coll_vfin[idx]['responses'][1]['rhoBoot']['CI'][1]
    df_vfin.loc[c].post_belief = docs_coll_vfin[idx]['responses'][2]['belief']
    df_vfin.loc[c].post_uncertainty_L = docs_coll_vfin[idx]['responses'][2]['uncertainty'][0]
    df_vfin.loc[c].post_uncertainty_R = docs_coll_vfin[idx]['responses'][2]['uncertainty'][1]
    df_vfin.loc[c].retro_prior = docs_coll_vfin[idx]['retroResponses'][0]['retroReasonVal_1']
    df_vfin.loc[c].retro_post1 = docs_coll_vfin[idx]['retroResponses'][0]['retroReasonVal_2']
    df_vfin.loc[c].retro_post2 = docs_coll_vfin[idx]['retroResponses'][0]['retroReasonVal_3']
    df_vfin.loc[c].tetris_location = 'pre-tetris'
    df_vfin.loc[c].likert = docs_coll_vfin[idx]['retroResponses'][0]['likert']
    df_vfin.loc[c].survey = docs_coll_vfin[idx]['survey']['freeform']

    c = c+1
    
    df_vfin.loc[c].ID = docs_coll_vfin[idx]['_id']
    df_vfin.loc[c].usertoken = docs_coll_vfin[idx]['usertoken']
    df_vfin.loc[c].prolificID = docs_coll_vfin[idx]['prequestionnaire']['profID']
    df_vfin.loc[c].gender = docs_coll_vfin[idx]['prequestionnaire']['genderRadios']
    df_vfin.loc[c].age = docs_coll_vfin[idx]['prequestionnaire']['age']
    df_vfin.loc[c].race = docs_coll_vfin[idx]['prequestionnaire']['raceRadios']
    df_vfin.loc[c].education = docs_coll_vfin[idx]['prequestionnaire']['eduRadios']
    df_vfin.loc[c].variables = docs_coll_vfin[idx]['variables'][0][0]
    df_vfin.loc[c].timerVal = 5
    df_vfin.loc[c].prior_belief = docs_coll_vfin[idx]['responses'][0]['belief']
    df_vfin.loc[c].prior_uncertainty_L = docs_coll_vfin[idx]['responses'][0]['uncertainty'][0]
    df_vfin.loc[c].prior_uncertainty_R = docs_coll_vfin[idx]['responses'][0]['uncertainty'][1]
    df_vfin.loc[c].data_rho = docs_coll_vfin[idx]['responses'][1]['rhoBoot']['pearsonr']
    df_vfin.loc[c].data_CI_L = docs_coll_vfin[idx]['responses'][1]['rhoBoot']['CI'][0]
    df_vfin.loc[c].data_CI_R = docs_coll_vfin[idx]['responses'][1]['rhoBoot']['CI'][1]
    df_vfin.loc[c].post_belief = docs_coll_vfin[idx]['responses'][3]['belief']
    df_vfin.loc[c].post_uncertainty_L = docs_coll_vfin[idx]['responses'][3]['uncertainty'][0]
    df_vfin.loc[c].post_uncertainty_R = docs_coll_vfin[idx]['responses'][3]['uncertainty'][1]
    df_vfin.loc[c].retro_prior = docs_coll_vfin[idx]['retroResponses'][0]['retroReasonVal_1']
    df_vfin.loc[c].retro_post1 = docs_coll_vfin[idx]['retroResponses'][0]['retroReasonVal_2']
    df_vfin.loc[c].retro_post2 = docs_coll_vfin[idx]['retroResponses'][0]['retroReasonVal_3']
    df_vfin.loc[c].tetris_location = 'post-tetris'
    df_vfin.loc[c].likert = docs_coll_vfin[idx]['retroResponses'][0]['likert']
    df_vfin.loc[c].survey = docs_coll_vfin[idx]['survey']['freeform']


    #####################################################################################################################
    c = c+ 1
    
    df_vfin.loc[c].ID = docs_coll_vfin[idx]['_id']
    df_vfin.loc[c].usertoken = docs_coll_vfin[idx]['usertoken']
    df_vfin.loc[c].prolificID = docs_coll_vfin[idx]['prequestionnaire']['profID']
    df_vfin.loc[c].gender = docs_coll_vfin[idx]['prequestionnaire']['genderRadios']
    df_vfin.loc[c].age = docs_coll_vfin[idx]['prequestionnaire']['age']
    df_vfin.loc[c].race = docs_coll_vfin[idx]['prequestionnaire']['raceRadios']
    df_vfin.loc[c].education = docs_coll_vfin[idx]['prequestionnaire']['eduRadios']
    df_vfin.loc[c].variables = docs_coll_vfin[idx]['variables'][1][0]
    df_vfin.loc[c].timerVal = 0
    df_vfin.loc[c].prior_belief = docs_coll_vfin[idx]['responses'][4]['belief']
    df_vfin.loc[c].prior_uncertainty_L = docs_coll_vfin[idx]['responses'][4]['uncertainty'][0]
    df_vfin.loc[c].prior_uncertainty_R = docs_coll_vfin[idx]['responses'][4]['uncertainty'][1]
    df_vfin.loc[c].data_rho = docs_coll_vfin[idx]['responses'][5]['rhoBoot']['pearsonr']
    df_vfin.loc[c].data_CI_L = docs_coll_vfin[idx]['responses'][5]['rhoBoot']['CI'][0]
    df_vfin.loc[c].data_CI_R = docs_coll_vfin[idx]['responses'][5]['rhoBoot']['CI'][1]
    df_vfin.loc[c].post_belief = docs_coll_vfin[idx]['responses'][6]['belief']
    df_vfin.loc[c].post_uncertainty_L = docs_coll_vfin[idx]['responses'][6]['uncertainty'][0]
    df_vfin.loc[c].post_uncertainty_R = docs_coll_vfin[idx]['responses'][6]['uncertainty'][1]
    df_vfin.loc[c].retro_prior = docs_coll_vfin[idx]['retroResponses'][1]['retroReasonVal_1']
    df_vfin.loc[c].retro_post1 = docs_coll_vfin[idx]['retroResponses'][1]['retroReasonVal_2']
    df_vfin.loc[c].retro_post2 = docs_coll_vfin[idx]['retroResponses'][1]['retroReasonVal_3']
    df_vfin.loc[c].tetris_location = 'pre-tetris'
    df_vfin.loc[c].likert = docs_coll_vfin[idx]['retroResponses'][1]['likert']
    df_vfin.loc[c].survey = docs_coll_vfin[idx]['survey']['freeform']
    
    c = c+1
    
    df_vfin.loc[c].ID = docs_coll_vfin[idx]['_id']
    df_vfin.loc[c].usertoken = docs_coll_vfin[idx]['usertoken']
    df_vfin.loc[c].prolificID = docs_coll_vfin[idx]['prequestionnaire']['profID']
    df_vfin.loc[c].gender = docs_coll_vfin[idx]['prequestionnaire']['genderRadios']
    df_vfin.loc[c].age = docs_coll_vfin[idx]['prequestionnaire']['age']
    df_vfin.loc[c].race = docs_coll_vfin[idx]['prequestionnaire']['raceRadios']
    df_vfin.loc[c].education = docs_coll_vfin[idx]['prequestionnaire']['eduRadios']
    df_vfin.loc[c].variables = docs_coll_vfin[idx]['variables'][1][0]
    df_vfin.loc[c].timerVal = 5
    df_vfin.loc[c].prior_belief = docs_coll_vfin[idx]['responses'][4]['belief']
    df_vfin.loc[c].prior_uncertainty_L = docs_coll_vfin[idx]['responses'][4]['uncertainty'][0]
    df_vfin.loc[c].prior_uncertainty_R = docs_coll_vfin[idx]['responses'][4]['uncertainty'][1]
    df_vfin.loc[c].data_rho = docs_coll_vfin[idx]['responses'][5]['rhoBoot']['pearsonr']
    df_vfin.loc[c].data_CI_L = docs_coll_vfin[idx]['responses'][5]['rhoBoot']['CI'][0]
    df_vfin.loc[c].data_CI_R = docs_coll_vfin[idx]['responses'][5]['rhoBoot']['CI'][1]
    df_vfin.loc[c].post_belief = docs_coll_vfin[idx]['responses'][7]['belief']
    df_vfin.loc[c].post_uncertainty_L = docs_coll_vfin[idx]['responses'][7]['uncertainty'][0]
    df_vfin.loc[c].post_uncertainty_R = docs_coll_vfin[idx]['responses'][7]['uncertainty'][1]
    df_vfin.loc[c].retro_prior = docs_coll_vfin[idx]['retroResponses'][1]['retroReasonVal_1']
    df_vfin.loc[c].retro_post1 = docs_coll_vfin[idx]['retroResponses'][1]['retroReasonVal_2']
    df_vfin.loc[c].retro_post2 = docs_coll_vfin[idx]['retroResponses'][1]['retroReasonVal_3']
    df_vfin.loc[c].tetris_location = 'post-tetris'
    df_vfin.loc[c].likert = docs_coll_vfin[idx]['retroResponses'][1]['likert']
    df_vfin.loc[c].survey = docs_coll_vfin[idx]['survey']['freeform']


    #####################################################################################################################
    c = c+ 1
    
    df_vfin.loc[c].ID = docs_coll_vfin[idx]['_id']
    df_vfin.loc[c].usertoken = docs_coll_vfin[idx]['usertoken']
    df_vfin.loc[c].prolificID = docs_coll_vfin[idx]['prequestionnaire']['profID']
    df_vfin.loc[c].gender = docs_coll_vfin[idx]['prequestionnaire']['genderRadios']
    df_vfin.loc[c].age = docs_coll_vfin[idx]['prequestionnaire']['age']
    df_vfin.loc[c].race = docs_coll_vfin[idx]['prequestionnaire']['raceRadios']
    df_vfin.loc[c].education = docs_coll_vfin[idx]['prequestionnaire']['eduRadios']
    df_vfin.loc[c].variables = docs_coll_vfin[idx]['variables'][2][0]
    df_vfin.loc[c].timerVal = 0   
    df_vfin.loc[c].prior_belief = docs_coll_vfin[idx]['responses'][8]['belief']
    df_vfin.loc[c].prior_uncertainty_L = docs_coll_vfin[idx]['responses'][8]['uncertainty'][0]
    df_vfin.loc[c].prior_uncertainty_R = docs_coll_vfin[idx]['responses'][8]['uncertainty'][1]
    df_vfin.loc[c].data_rho = docs_coll_vfin[idx]['responses'][9]['rhoBoot']['pearsonr']
    df_vfin.loc[c].data_CI_L = docs_coll_vfin[idx]['responses'][9]['rhoBoot']['CI'][0]
    df_vfin.loc[c].data_CI_R = docs_coll_vfin[idx]['responses'][9]['rhoBoot']['CI'][1]
    df_vfin.loc[c].post_belief = docs_coll_vfin[idx]['responses'][10]['belief']
    df_vfin.loc[c].post_uncertainty_L = docs_coll_vfin[idx]['responses'][10]['uncertainty'][0]
    df_vfin.loc[c].post_uncertainty_R = docs_coll_vfin[idx]['responses'][10]['uncertainty'][1]
    df_vfin.loc[c].retro_prior = docs_coll_vfin[idx]['retroResponses'][2]['retroReasonVal_1']
    df_vfin.loc[c].retro_post1 = docs_coll_vfin[idx]['retroResponses'][2]['retroReasonVal_2']
    df_vfin.loc[c].retro_post2 = docs_coll_vfin[idx]['retroResponses'][2]['retroReasonVal_3']
    df_vfin.loc[c].tetris_location = 'pre-tetris'
    df_vfin.loc[c].likert = docs_coll_vfin[idx]['retroResponses'][2]['likert']
    df_vfin.loc[c].survey = docs_coll_vfin[idx]['survey']['freeform']
    
    c = c+1
    
    df_vfin.loc[c].ID = docs_coll_vfin[idx]['_id']
    df_vfin.loc[c].usertoken = docs_coll_vfin[idx]['usertoken']
    df_vfin.loc[c].prolificID = docs_coll_vfin[idx]['prequestionnaire']['profID']
    df_vfin.loc[c].gender = docs_coll_vfin[idx]['prequestionnaire']['genderRadios']
    df_vfin.loc[c].age = docs_coll_vfin[idx]['prequestionnaire']['age']
    df_vfin.loc[c].race = docs_coll_vfin[idx]['prequestionnaire']['raceRadios']
    df_vfin.loc[c].education = docs_coll_vfin[idx]['prequestionnaire']['eduRadios']
    df_vfin.loc[c].variables = docs_coll_vfin[idx]['variables'][2][0]
    df_vfin.loc[c].timerVal = 5    
    df_vfin.loc[c].prior_belief = docs_coll_vfin[idx]['responses'][8]['belief']
    df_vfin.loc[c].prior_uncertainty_L = docs_coll_vfin[idx]['responses'][8]['uncertainty'][0]
    df_vfin.loc[c].prior_uncertainty_R = docs_coll_vfin[idx]['responses'][8]['uncertainty'][1]
    df_vfin.loc[c].data_rho = docs_coll_vfin[idx]['responses'][9]['rhoBoot']['pearsonr']
    df_vfin.loc[c].data_CI_L = docs_coll_vfin[idx]['responses'][9]['rhoBoot']['CI'][0]
    df_vfin.loc[c].data_CI_R = docs_coll_vfin[idx]['responses'][9]['rhoBoot']['CI'][1]
    df_vfin.loc[c].post_belief = docs_coll_vfin[idx]['responses'][11]['belief']
    df_vfin.loc[c].post_uncertainty_L = docs_coll_vfin[idx]['responses'][11]['uncertainty'][0]
    df_vfin.loc[c].post_uncertainty_R = docs_coll_vfin[idx]['responses'][11]['uncertainty'][1]
    df_vfin.loc[c].retro_prior = docs_coll_vfin[idx]['retroResponses'][2]['retroReasonVal_1']
    df_vfin.loc[c].retro_post1 = docs_coll_vfin[idx]['retroResponses'][2]['retroReasonVal_2']
    df_vfin.loc[c].retro_post2 = docs_coll_vfin[idx]['retroResponses'][2]['retroReasonVal_3']
    df_vfin.loc[c].tetris_location = 'post-tetris'
    df_vfin.loc[c].likert = docs_coll_vfin[idx]['retroResponses'][2]['likert']
    df_vfin.loc[c].survey = docs_coll_vfin[idx]['survey']['freeform']


    c = c+ 1
    
print(c)
# Out:
# 612

# %%
df_vfin
# Out:
#                            ID usertoken                prolificID  gender age  \
# 0    62f67ae0fc70763173e81fc2  Swh7B1VF  60ca3935fb64d56e11014643  female  23
# 1    62f67ae0fc70763173e81fc2  Swh7B1VF  60ca3935fb64d56e11014643  female  23
# 2    62f67ae0fc70763173e81fc2  Swh7B1VF  60ca3935fb64d56e11014643  female  23
# 3    62f67ae0fc70763173e81fc2  Swh7B1VF  60ca3935fb64d56e11014643  female  23
# 4    62f67ae0fc70763173e81fc2  Swh7B1VF  60ca3935fb64d56e11014643  female  23
# ..                        ...       ...                       ...     ...  ..
# 607  62fabb0c930ab57fc9fe19fb  vx2CYiXG  62f31911f6572d09a0e47369    male  21
# 608  62fabb0c930ab57fc9fe19fb  vx2CYiXG  62f31911f6572d09a0e47369    male  21
# 609  62fabb0c930ab57fc9fe19fb  vx2CYiXG  62f31911f6572d09a0e47369    male  21
# 610  62fabb0c930ab57fc9fe19fb  vx2CYiXG  62f31911f6572d09a0e47369    male  21
# 611  62fabb0c930ab57fc9fe19fb  vx2CYiXG  62f31911f6572d09a0e47369    male  21
#
# ...

# %%
df_vfin.to_csv('pilot_belief_vfin_large.csv', index=True)

# %%
##################################### PLOTS #####################################

# %%
df_fin = pd.read_csv("pilot_belief_vfin.csv")
df_fin = df_fin.drop(['Unnamed: 0'], axis = 1)

# %%
df_fin
# Out:
# 0                 ['Immigrant population', 'Crime rate']
# 1                       ['Years of education', 'Income']
# 2      ['Avg. hours on social media', 'Depression sev...
# 3                 ['Immigrant population', 'Crime rate']
# 4                       ['Years of education', 'Income']
#                              ...
# 301    ['Avg. hours on social media', 'Depression sev...
# 302               ['Immigrant population', 'Crime rate']
# 303    ['Avg. hours on social media', 'Depression sev...
# 304                     ['Years of education', 'Income']
# 305               ['Immigrant population', 'Crime rate']
# Name: variables, Length: 306, dtype: object

# %%
df_fin_IPCR = df_fin[df_fin['variables'].str.contains('Immigrant population')]
df_fin_SMDR = df_fin[df_fin['variables'].str.contains('Avg. hours on social media')]
df_fin_EIR = df_fin[df_fin['variables'].str.contains('Years of education')]

# %%
df_fin_IPCR = df_fin_IPCR.reset_index(drop = True)
df_fin_SMDR = df_fin_SMDR.reset_index(drop = True)
df_fin_EIR = df_fin_EIR.reset_index(drop = True)

# %%
df_fin_EIR.columns
# Out:
# Index(['ID', 'usertoken', 'prolificID', 'gender', 'age', 'race', 'education',
#        'variables', 'timerVal', 'prior_belief', 'prior_uncertainty_L',
#        'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R',
#        'post1_belief', 'post1_uncertainty_L', 'post1_uncertainty_R',
#        'post2_belief', 'post2_uncertainty_L', 'post2_uncertainty_R',
#        'retro_prior', 'retro_post1', 'retro_post2', 'likert', 'survey'],
#       dtype='object')

# %%
df_fin_IPCR
# Out:
#                            ID usertoken                prolificID  gender  \
# 0    62f67ae0fc70763173e81fc2  Swh7B1VF  60ca3935fb64d56e11014643  female
# 1    62f67f44fc70763173e81fdc  OwNbjsPH  5af9fab60a7ecb00011820b8  female
# 2    62f68027fc70763173e81fe0  MAXHFRS7  629fbe8ae956f7cb13de5073  female
# 3    62f6808bfc70763173e81fe9  RWrfFb2U  60baaa995c09d3162511871d    male
# 4    62f68266fc70763173e8200b  GL2yYGVe  6287a8c4a6303ff156cd0853    male
# ..                        ...       ...                       ...     ...
# 97   62faa37f930ab57fc9fe194e  hfXkNsfz  6107f8812249eaf730bf4688  female
# 98   62faa683930ab57fc9fe197f  Zb0GxTDm  5f4d84f6835880a75c96c966    male
# 99   62faa77d930ab57fc9fe198c  rJ0xFotM  5d51ffd641a6aa0019ca73df    male
# 100  62faa8ab930ab57fc9fe19a0  iTVlm8Ep  5ae5374253072800018d5c69    male
# 101  62fabb0c930ab57fc9fe19fb  vx2CYiXG  62f31911f6572d09a0e47369    male
#
#      age       race   education                               variables  \
# ...

# %%
################################## Immigrant Population ##################################

# %%
df_fin_IPCR[['age', 'prior_belief', 'prior_uncertainty_L', 'prior_uncertainty_R', 'data_rho',
       'data_CI_L', 'data_CI_R', 'post1_belief', 'post1_uncertainty_L', 'post1_uncertainty_R', 'post2_belief', 'post2_uncertainty_L','post2_uncertainty_R']] = df_fin_IPCR[['age', 'prior_belief', 'prior_uncertainty_L', 'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R', 
         'post1_belief', 'post1_uncertainty_L', 'post1_uncertainty_R', 'post2_belief', 'post2_uncertainty_L','post2_uncertainty_R']].apply(pd.to_numeric)

# %%
df_IPCR_plot = pd.DataFrame()

# %%
df_IPCR_plot['corr_diff_data_post1'] = abs(df_fin_IPCR['data_rho'] - df_fin_IPCR['post1_belief'])
df_IPCR_plot['corr_diff_data_post2'] = abs(df_fin_IPCR['data_rho'] - df_fin_IPCR['post2_belief'])

df_IPCR_plot['corr_diff_data_post1_notAbs'] = df_fin_IPCR['data_rho'] - df_fin_IPCR['post1_belief']
df_IPCR_plot['corr_diff_data_post2_notAbs'] = df_fin_IPCR['data_rho'] - df_fin_IPCR['post2_belief']

df_IPCR_plot['corr_diff_prior_post1'] = abs(df_fin_IPCR['prior_belief'] - df_fin_IPCR['post1_belief'])
df_IPCR_plot['corr_diff_prior_post2'] = abs(df_fin_IPCR['prior_belief'] - df_fin_IPCR['post2_belief'])

df_IPCR_plot['corr_diff_prior_post1_notAbs'] = abs(df_fin_IPCR['prior_belief'] - df_fin_IPCR['post1_belief'])
df_IPCR_plot['corr_diff_prior_post2_notAbs'] = abs(df_fin_IPCR['prior_belief'] - df_fin_IPCR['post2_belief'])

# %%
df_IPCR_plot
# Out:
#      corr_diff_data_post1  corr_diff_data_post2  corr_diff_prior_post1  \
# 0                0.100866              0.089409               1.244300
# 1                0.371926              0.247756               0.518344
# 2                0.272366              0.368940               0.566966
# 3                0.322205              0.361729               0.660615
# 4                0.246785              0.125051               1.106373
# ..                    ...                   ...                    ...
# 97               0.427098              0.118417               0.376921
# 98               0.293419              0.233098               1.120045
# 99               0.807001              0.143117               0.192081
# 100              0.101120              0.829793               0.836620
# 101              0.828063              0.759580               0.117308
#
#      corr_diff_prior_post2
# 0                 1.232843
# 1                 0.642514
# 2                 0.470392
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (13,13))

corrplot = sns.scatterplot(x= df_IPCR_plot['corr_diff_data_post1'], y= 0.0, linestyle='-', marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_IPCR_plot['corr_diff_data_post2'], y= 0.5, linestyle='-', marker = 'o', s = 200)
corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('Correlation Difference [Varaible: Immigrant Population x Crime Rate]', fontsize = 17)
corrplot.set_yticks([0.0, 0.5])
corrplot.set_yticklabels(['post1-data [t=0]', 'post2-data [t=5]'])
# plt.savefig("correlation_vfin_IPCR.png")
# Out:
# [Text(0, 0, 'post1-data [t=0]'), Text(0, 0, 'post2-data [t=5]')]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (13,13))

corrplot = sns.scatterplot(x= df_IPCR_plot['corr_diff_data_post1_notAbs'], y= 0.0, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_IPCR_plot['corr_diff_data_post2_notAbs'], y= 0.5, marker = 'o', s = 200)
corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('Correlation Difference [Varaible: Immigrant Population x Crime Rate]', fontsize = 17)
corrplot.set_yticks([0.0, 0.5])
corrplot.set_yticklabels(['post1-data [t=0]', 'post2-data [t=5]'])
plt.savefig("correlation_vfin_IPCR_notAbs.png")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (13,13))

df_IPCR_bp = df_IPCR_plot[['corr_diff_data_post1', 'corr_diff_data_post2']]
corrplot = sns.boxplot(x = "variable", y = "value", data = pd.melt(df_IPCR_bp), width = 0.3)
corrplot.set_xlabel('Timer Value', fontsize = 17)
corrplot.set_ylabel('Correlation Difference [Posterior - Data]', fontsize = 17)
corrplot.set_xticklabels(['t=0', 't=5'], fontsize = 14)
corrplot.set_title('Immigrant Population x Crime Rate', fontsize = 17)
plt.savefig("boxplot_corrDataPost_IPCR.png")

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# %%
df_Lfin = pd.read_csv("pilot_belief_vfin_large.csv")
df_Lfin = df_Lfin.drop(['Unnamed: 0'], axis = 1)

# %%
df_Lfin.columns
# Out:
# Index(['ID', 'usertoken', 'prolificID', 'gender', 'age', 'race', 'education',
#        'variables', 'timerVal', 'prior_belief', 'prior_uncertainty_L',
#        'prior_uncertainty_R', 'data_rho', 'data_CI_L', 'data_CI_R',
#        'post_belief', 'post_uncertainty_L', 'post_uncertainty_R',
#        'retro_prior', 'retro_post1', 'retro_post2', 'tetris_location',
#        'likert', 'survey'],
#       dtype='object')

# %%
df_Lfin_IPCR = df_Lfin[df_Lfin['variables'].str.contains('Immigrant population')]
df_Lfin_SMDR = df_Lfin[df_Lfin['variables'].str.contains('Avg. hours on social media')]
df_Lfin_EIR = df_Lfin[df_Lfin['variables'].str.contains('Years of education')]

# %%
df_Lfin_IPCR = df_Lfin_IPCR.reset_index(drop = True)
df_Lfin_SMDR = df_Lfin_SMDR.reset_index(drop = True)
df_Lfin_EIR = df_Lfin_EIR.reset_index(drop = True)

# %%
df_Lfin_IPCR['timerVal']
# Out:
# 0      0
# 1      5
# 2      0
# 3      5
# 4      0
#       ..
# 199    5
# 200    0
# 201    5
# 202    0
# 203    5
# Name: timerVal, Length: 204, dtype: int64

# %%
X_coords = np.array([df_Lfin_IPCR.query('timerVal==0').prior_belief, df_Lfin_IPCR.query('timerVal==5').prior_belief])
Y_coords = np.array([df_Lfin_IPCR.query('timerVal==0').post_belief, df_Lfin_IPCR.query('timerVal==5').post_belief])
X_coords.shape, Y_coords.shape
# Out:
# ((2, 102), (2, 102))

# %%
plt.figure(figsize = (20,20))

colors = {0:'pink', 5:'navy'}
pink_patch = mpatches.Patch(color='pink', label='Posterior t=0 min')
navy_patch = mpatches.Patch(color='navy', label='Posterior t=5 min')

plt.scatter(x = df_Lfin_IPCR.prior_belief, y = df_Lfin_IPCR.post_belief, c = df_Lfin_IPCR.timerVal.map(colors), s = 200, alpha=0.6)
plt.plot(X_coords, Y_coords, color='gray')
plt.xlabel("Prior",fontweight ='bold', size = 17)
plt.ylabel("Posterior", fontweight ='bold',size = 17)
plt.legend(handles=[pink_patch, navy_patch], fontsize = "x-large")
plt.title('Immigrant Population x Crime Rate', fontsize = 17)
plt.savefig("IPCR_pairedscatter.png")

# %%
X_coords = np.array([df_fin_IPCR.prior_belief, df_fin_IPCR.post1_belief])
Y_coords = np.array([df_fin_IPCR.prior_belief, df_fin_IPCR.post2_belief])
X_coords.shape, Y_coords.shape

# %%
plt.figure(figsize = (13,13))

plt.scatter(x = df_fin_IPCR.prior_belief, y = df_fin_IPCR.post1_belief, c = 'navy', s = 200, alpha=0.6, marker = '*')
plt.scatter(x = df_fin_IPCR.prior_belief, y = df_fin_IPCR.post2_belief, c = 'pink', s = 200, alpha=0.6, marker = 'o')

plt.xlabel("Prior",fontweight ='bold', size=14)
plt.ylabel("Posterior", fontweight ='bold',size=14)
# Out:
# Text(0, 0.5, 'Posterior')

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_IPCR_plot['corr_diff_prior_post1'], y= df_IPCR_plot['corr_diff_prior_post2'], marker = 'o', s = 200, c='violet', alpha=0.6)
plt.xlabel('Posterior 1 - Prior', fontsize = 17)
plt.ylabel('Posterior 2 - Prior', fontsize = 17)
plt.title('Immigrant Population x Crime Rate [Absolute]', fontsize = 17)
plt.savefig("IPCR_comparePriorPosterior.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_IPCR_plot['corr_diff_prior_post1'], y= df_IPCR_plot['corr_diff_prior_post2'], marker = 'o', s = 200, c='violet', alpha=0.6)
sns.regplot(df_IPCR_plot.corr_diff_prior_post1, df_IPCR_plot.corr_diff_prior_post2, ci = None)

plt.xlabel('Posterior 1 - Prior', fontsize = 17)
plt.ylabel('Posterior 2 - Prior', fontsize = 17)
plt.title('Immigrant Population x Crime Rate [Absolute]', fontsize = 17)
plt.savefig("IPCR_regPriorPosterior.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_IPCR_plot['corr_diff_data_post1'], y= df_IPCR_plot['corr_diff_data_post2'], marker = 'o', s = 200, c='dimgrey', alpha=0.6)
plt.xlabel('Posterior 1 - Data', fontsize = 17)
plt.ylabel('Posterior 2 - Data', fontsize = 17)
plt.title('Immigrant Population x Crime Rate [Absolute]', fontsize = 17)
plt.savefig("IPCR_compareDataPosterior.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_IPCR_plot['corr_diff_data_post1'], y= df_IPCR_plot['corr_diff_data_post2'], marker = 'o', s = 200, c='dimgrey', alpha=0.6)
sns.regplot(df_IPCR_plot.corr_diff_data_post1, df_IPCR_plot.corr_diff_data_post2, ci = None)

plt.xlabel('Posterior 1 - Data', fontsize = 17)
plt.ylabel('Posterior 2 - Data', fontsize = 17)
plt.title('Immigrant Population x Crime Rate [Absolute]', fontsize = 17)
plt.savefig("IPCR_regDataPosterior.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_IPCR_plot['corr_diff_prior_post1_notAbs'], y = df_IPCR_plot['corr_diff_prior_post2_notAbs'], marker = 'o', s = 200, c='violet', alpha=0.6)
plt.xlabel('Posterior 1 - Prior', fontsize = 17)
plt.ylabel('Posterior 2 - Prior', fontsize = 17)
plt.title('Immigrant Population x Crime Rate [Not Absolute]', fontsize = 17)
plt.savefig("IPCR_comparePriorPosterior_notAbs.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_IPCR_plot['corr_diff_prior_post1_notAbs'], y = df_IPCR_plot['corr_diff_prior_post2_notAbs'], marker = 'o', s = 200, c='violet', alpha=0.6)
sns.regplot(df_IPCR_plot.corr_diff_prior_post1_notAbs, df_IPCR_plot.corr_diff_prior_post2_notAbs, ci = None)

plt.xlabel('Posterior 1 - Prior', fontsize = 17)
plt.ylabel('Posterior 2 - Prior', fontsize = 17)
plt.title('Immigrant Population x Crime Rate [Not Absolute]', fontsize = 17)
plt.savefig("IPCR_regPriorPosterior_notAbs.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_IPCR_plot['corr_diff_data_post1_notAbs'], y= df_IPCR_plot['corr_diff_data_post2_notAbs'], marker = 'o', s = 200, c='dimgrey', alpha=0.6)
plt.xlabel('Posterior 1 - Data', fontsize = 17)
plt.ylabel('Posterior 2 - Data', fontsize = 17)
plt.title('Immigrant Population x Crime Rate [Absolute]', fontsize = 17)
plt.savefig("IPCR_compareDataPosterior_notAbs.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_IPCR_plot['corr_diff_data_post1_notAbs'], y= df_IPCR_plot['corr_diff_data_post2_notAbs'], marker = 'o', s = 200, c='dimgrey', alpha=0.6)
sns.regplot(df_IPCR_plot.corr_diff_data_post1_notAbs, df_IPCR_plot.corr_diff_data_post2_notAbs, ci = None)

plt.xlabel('Posterior 1 - Data', fontsize = 17)
plt.ylabel('Posterior 2 - Data', fontsize = 17)
plt.title('Immigrant Population x Crime Rate [Absolute]', fontsize = 17)
plt.savefig("IPCR_regDataPosterior_notAbs.png")

# %%
################################## Social Media Hours ##################################

# %%
df_SMDR_plot = pd.DataFrame()

# %%
df_SMDR_plot['corr_diff_data_post1'] = abs(df_fin_SMDR['data_rho'] - df_fin_SMDR['post1_belief'])
df_SMDR_plot['corr_diff_data_post2'] = abs(df_fin_SMDR['data_rho'] - df_fin_SMDR['post2_belief'])

df_SMDR_plot['corr_diff_data_post1_notAbs'] = df_fin_SMDR['data_rho'] - df_fin_SMDR['post1_belief']
df_SMDR_plot['corr_diff_data_post2_notAbs'] = df_fin_SMDR['data_rho'] - df_fin_SMDR['post2_belief']

df_SMDR_plot['corr_diff_prior_post1'] = abs(df_fin_SMDR['prior_belief'] - df_fin_SMDR['post1_belief'])
df_SMDR_plot['corr_diff_prior_post2'] = abs(df_fin_SMDR['prior_belief'] - df_fin_SMDR['post2_belief'])

df_SMDR_plot['corr_diff_prior_post1_notAbs'] = df_fin_SMDR['prior_belief'] - df_fin_SMDR['post1_belief']
df_SMDR_plot['corr_diff_prior_post2_notAbs'] = df_fin_SMDR['prior_belief'] - df_fin_SMDR['post2_belief']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (13,13))

corrplot = sns.scatterplot(x= df_SMDR_plot['corr_diff_data_post1'], y= 0.0, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_SMDR_plot['corr_diff_data_post2'], y= 0.5, marker = 'o', s = 200)
corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('Correlation Difference [Varaible: Social Media Hours x Depression Rate]', fontsize = 17)
corrplot.set_yticks([0.0, 0.5])
corrplot.set_yticklabels(['post1-data [t=0]', 'post2-data [t=5]'])
plt.savefig("correlation__vfin_SMDR.png")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (13,13))

corrplot = sns.scatterplot(x= df_SMDR_plot['corr_diff_data_post1_notAbs'], y= 0.0, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_SMDR_plot['corr_diff_data_post2_notAbs'], y= 0.5, marker = 'o', s = 200)
corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('Correlation Difference [Varaible: Social Media Hours x Depression Rate]', fontsize = 17)
corrplot.set_yticks([0.0, 0.5])
corrplot.set_yticklabels(['post1-data [t=0]', 'post2-data [t=5]'])
plt.savefig("correlation__vfin_SMDR_notAbs.png")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (13,13))

df_SMDR_bp = df_SMDR_plot[['corr_diff_data_post1', 'corr_diff_data_post2']]
corrplot = sns.boxplot(x = "variable", y = "value", data = pd.melt(df_SMDR_bp), width = 0.3)
corrplot.set_xlabel('Timer Value', fontsize = 17)
corrplot.set_ylabel('Correlation Difference [Posterior - Data]', fontsize = 17)
corrplot.set_xticklabels(['t=0', 't=5'], fontsize = 14)
corrplot.set_title('Social Media Hours x Depression Rate', fontsize = 17)
plt.savefig("boxplot_corrDataPost_SMDR.png")

# %%
X_coords = np.array([df_Lfin_SMDR.query('timerVal==0').prior_belief, df_Lfin_SMDR.query('timerVal==5').prior_belief])
Y_coords = np.array([df_Lfin_SMDR.query('timerVal==0').post_belief, df_Lfin_SMDR.query('timerVal==5').post_belief])
X_coords.shape, Y_coords.shape
# Out:
# ((2, 102), (2, 102))

# %%
plt.figure(figsize = (20,20))

colors = {0:'pink', 5:'navy'}
pink_patch = mpatches.Patch(color='pink', label='Posterior t=0 min')
navy_patch = mpatches.Patch(color='navy', label='Posterior t=5 min')

plt.scatter(x = df_Lfin_SMDR.prior_belief, y = df_Lfin_SMDR.post_belief, c = df_Lfin_SMDR.timerVal.map(colors), s = 200, alpha=0.6)
plt.plot(X_coords, Y_coords, color='gray')
plt.xlabel("Prior",fontweight ='bold', size = 17)
plt.ylabel("Posterior", fontweight ='bold',size = 17)
plt.legend(handles=[pink_patch, navy_patch], fontsize = "x-large")
plt.title('Hours on Social Media x Depression Rate', fontsize = 17)
plt.savefig("SMDR_pairedscatter.png")

# %%
from sklearn.linear_model import LinearRegression

plt.figure(figsize = (10,8))
plt.scatter(x = df_SMDR_plot['corr_diff_prior_post1'], y= df_SMDR_plot['corr_diff_prior_post2'], marker = 'o', s = 200, c='orange', alpha=0.6)
plt.xlabel('Posterior 1 - Prior', fontsize = 17)
plt.ylabel('Posterior 2 - Prior', fontsize = 17)
plt.title('Hours on Social Media x Depression Rate [Absolute]', fontsize = 17)
plt.savefig("SMDR_comparePriorPosterior.png")

# %%
from sklearn.linear_model import LinearRegression

plt.figure(figsize = (10,8))
plt.scatter(x = df_SMDR_plot['corr_diff_prior_post1'], y= df_SMDR_plot['corr_diff_prior_post2'], marker = 'o', s = 200, c='orange', alpha=0.6)
sns.regplot(df_SMDR_plot.corr_diff_prior_post1, df_SMDR_plot.corr_diff_prior_post2, ci=None)

plt.xlabel('Posterior 1 - Prior', fontsize = 17)
plt.ylabel('Posterior 2 - Prior', fontsize = 17)
plt.title('Hours on Social Media x Depression Rate [Absolute]', fontsize = 17)
plt.savefig("SMDR_regPriorPosterior.png")
# df_SMDR_plot['corr_diff_prior_post1']

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_SMDR_plot['corr_diff_data_post1'], y= df_SMDR_plot['corr_diff_data_post2'], marker = 'o', s = 200, c='seagreen', alpha=0.6)
plt.xlabel('Posterior 1 - Data', fontsize = 17)
plt.ylabel('Posterior 2 - Data', fontsize = 17)
plt.title('Hours on Social Media x Depression Rate [Absolute]', fontsize = 17)
plt.savefig("SMDR_compareDataPosterior.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_SMDR_plot['corr_diff_data_post1'], y= df_SMDR_plot['corr_diff_data_post2'], marker = 'o', s = 200, c='seagreen', alpha=0.6)
sns.regplot(df_SMDR_plot.corr_diff_data_post1, df_SMDR_plot.corr_diff_data_post2, ci=None)

plt.xlabel('Posterior 1 - Data', fontsize = 17)
plt.ylabel('Posterior 2 - Data', fontsize = 17)
plt.title('Hours on Social Media x Depression Rate [Absolute]', fontsize = 17)
plt.savefig("SMDR_regDataPosterior.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_SMDR_plot['corr_diff_prior_post1_notAbs'], y= df_SMDR_plot['corr_diff_prior_post2_notAbs'], marker = 'o', s = 200, c='orange', alpha=0.6)
plt.xlabel('Posterior 1 - Prior', fontsize = 17)
plt.ylabel('Posterior 2 - Prior', fontsize = 17)
plt.title('Hours on Social Media x Depression Rate [Not Absolute]', fontsize = 17)
plt.savefig("SMDR_comparePriorPosterior_notAbs.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_SMDR_plot['corr_diff_prior_post1_notAbs'], y= df_SMDR_plot['corr_diff_prior_post2_notAbs'], marker = 'o', s = 200, c='orange', alpha=0.6)
sns.regplot(df_SMDR_plot.corr_diff_prior_post1_notAbs, df_SMDR_plot.corr_diff_prior_post2_notAbs, ci=None)

plt.xlabel('Posterior 1 - Prior', fontsize = 17)
plt.ylabel('Posterior 2 - Prior', fontsize = 17)
plt.title('Hours on Social Media x Depression Rate [Not Absolute]', fontsize = 17)
plt.savefig("SMDR_regPriorPosterior_notAbs.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_SMDR_plot['corr_diff_data_post1_notAbs'], y= df_SMDR_plot['corr_diff_data_post2_notAbs'], marker = 'o', s = 200, c='seagreen', alpha=0.6)
plt.xlabel('Posterior 1 - Data', fontsize = 17)
plt.ylabel('Posterior 2 - Data', fontsize = 17)
plt.title('Hours on Social Media x Depression Rate [Not Absolute]', fontsize = 17)
plt.savefig("SMDR_compareDataPosterior_notAbs.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_SMDR_plot['corr_diff_data_post1_notAbs'], y= df_SMDR_plot['corr_diff_data_post2_notAbs'], marker = 'o', s = 200, c='seagreen', alpha=0.6)
sns.regplot(df_SMDR_plot.corr_diff_data_post1_notAbs, df_SMDR_plot.corr_diff_data_post2_notAbs, ci=None)

plt.xlabel('Posterior 1 - Data', fontsize = 17)
plt.ylabel('Posterior 2 - Data', fontsize = 17)
plt.title('Hours on Social Media x Depression Rate [Not Absolute]', fontsize = 17)
plt.savefig("SMDR_regDataPosterior_notAbs.png")

# %%
################################## Years of Education ##################################

# %%
df_EIR_plot = pd.DataFrame()

# %%
df_EIR_plot['corr_diff_data_post1'] = abs(df_fin_EIR['data_rho'] - df_fin_EIR['post1_belief'])
df_EIR_plot['corr_diff_data_post2'] = abs(df_fin_EIR['data_rho'] - df_fin_EIR['post2_belief'])

df_EIR_plot['corr_diff_data_post1_notAbs'] = df_fin_EIR['data_rho'] - df_fin_EIR['post1_belief']
df_EIR_plot['corr_diff_data_post2_notAbs'] = df_fin_EIR['data_rho'] - df_fin_EIR['post2_belief']

df_EIR_plot['corr_diff_prior_post1'] = abs(df_fin_EIR['prior_belief'] - df_fin_EIR['post1_belief'])
df_EIR_plot['corr_diff_prior_post2'] = abs(df_fin_EIR['prior_belief'] - df_fin_EIR['post2_belief'])

df_EIR_plot['corr_diff_prior_post1_notAbs'] = df_fin_EIR['prior_belief'] - df_fin_EIR['post1_belief']
df_EIR_plot['corr_diff_prior_post2_notAbs'] = df_fin_EIR['prior_belief'] - df_fin_EIR['post2_belief']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (7,7))

corrplot = sns.scatterplot(x= df_EIR_plot['corr_diff_data_post1'], y= 0.0, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_EIR_plot['corr_diff_data_post2'], y= 0.5, marker = 'o', s = 200)
corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('Correlation Difference [Varaible: Years of Education x Income Rate]', fontsize = 17)
corrplot.set_yticks([0.0, 0.5])
corrplot.set_yticklabels(['post1-data [t=0]', 'post2-data [t=5]'])
plt.savefig("correlation_vfin_EIR.png")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (13,13))

corrplot = sns.scatterplot(x= df_EIR_plot['corr_diff_data_post1_notAbs'], y= 0.0, marker = 'o', s = 200)
corrplot = sns.scatterplot(x= df_EIR_plot['corr_diff_data_post2_notAbs'], y= 0.5, marker = 'o', s = 200)
corrplot.set_ylabel('Timer Value', fontsize = 17)
corrplot.set_xlabel('Correlation Difference [Varaible: Years of Education x Income Rate]', fontsize = 17)
corrplot.set_yticks([0.0, 0.5])
corrplot.set_yticklabels(['post1-data [t=0]', 'post2-data [t=5]'])
plt.savefig("correlation_vfin_EIR_notAbs.png")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (13,13))

df_EIR_bp = df_EIR_plot[['corr_diff_data_post1', 'corr_diff_data_post2']]
corrplot = sns.boxplot(x = "variable", y = "value", data = pd.melt(df_EIR_bp), width = 0.3)
corrplot.set_xlabel('Timer Value', fontsize = 17)
corrplot.set_ylabel('Correlation Difference [Posterior - Data]', fontsize = 17)
corrplot.set_xticklabels(['t=0', 't=5'], fontsize = 14)
corrplot.set_title('Years of Education x Income Rate', fontsize = 17)
plt.savefig("boxplot_corrDataPost_EIR.png")

# %%
X_coords = np.array([df_Lfin_EIR.query('timerVal==0').prior_belief, df_Lfin_EIR.query('timerVal==5').prior_belief])
Y_coords = np.array([df_Lfin_EIR.query('timerVal==0').post_belief, df_Lfin_EIR.query('timerVal==5').post_belief])
X_coords.shape, Y_coords.shape
# Out:
# ((2, 102), (2, 102))

# %%
plt.figure(figsize = (10,8))

colors = {0:'pink', 5:'navy'}
pink_patch = mpatches.Patch(color='pink', label='Posterior t=0 min')
navy_patch = mpatches.Patch(color='navy', label='Posterior t=5 min')

plt.scatter(x = df_Lfin_EIR.prior_belief, y = df_Lfin_EIR.post_belief, c = df_Lfin_EIR.timerVal.map(colors), s = 200, alpha=0.6)
plt.plot(X_coords, Y_coords, color='gray')
plt.xlabel("Prior",fontweight ='bold', size = 17)
plt.ylabel("Posterior", fontweight ='bold',size = 17)
plt.legend(handles=[pink_patch, navy_patch], fontsize = "x-large")
plt.title('Years of Education x Income', fontsize = 17)
plt.savefig("EIR_pairedscatter.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4663b9942c04> in <module>
# ----> 1 plt.figure(figsize = (10,8))
#       2
#       3 colors = {0:'pink', 5:'navy'}
#       4 pink_patch = mpatches.Patch(color='pink', label='Posterior t=0 min')
#       5 navy_patch = mpatches.Patch(color='navy', label='Posterior t=5 min')
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_EIR_plot['corr_diff_prior_post1'], y= df_EIR_plot['corr_diff_prior_post2'], marker = 'o', s = 200, c='firebrick', alpha=0.6)
plt.xlabel('Posterior 1 - Prior', fontsize = 17)
plt.ylabel('Posterior 2 - Prior', fontsize = 17)
plt.title('Years of Education x Income [Absolute]', fontsize = 17)
plt.savefig("EIR_comparePriorPosterior.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_EIR_plot['corr_diff_prior_post1'], y= df_EIR_plot['corr_diff_prior_post2'], marker = 'o', s = 200, c='firebrick', alpha=0.6)
# sns.scatterplot(x = df_EIR_plot['corr_diff_prior_post1'], y= df_EIR_plot['corr_diff_prior_post2'], markers = 'o', alpha=0.6)
sns.regplot(df_EIR_plot.corr_diff_prior_post1, df_EIR_plot.corr_diff_prior_post2, ci=None)
plt.xlabel('Posterior 1 - Prior', fontsize = 17)
plt.ylabel('Posterior 2 - Prior', fontsize = 17)
plt.title('Years of Education x Income [Absolute]', fontsize = 17)
plt.savefig("EIR_regPriorPosterior.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_EIR_plot['corr_diff_data_post1'], y= df_EIR_plot['corr_diff_data_post2'], marker = 'o', s = 200, c='navy', alpha=0.6)
plt.xlabel('Posterior 1 - Data', fontsize = 17)
plt.ylabel('Posterior 2 - Data', fontsize = 17)
plt.title('Years of Education x Income [Absolute]', fontsize = 17)
plt.savefig("EIR_compareDataPosterior.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_EIR_plot['corr_diff_data_post1'], y= df_EIR_plot['corr_diff_data_post2'], marker = 'o', s = 200, c='navy', alpha=0.6)
sns.regplot(df_EIR_plot.corr_diff_data_post1, df_EIR_plot.corr_diff_data_post2, ci=None)

plt.xlabel('Posterior 1 - Data', fontsize = 17)
plt.ylabel('Posterior 2 - Data', fontsize = 17)
plt.title('Years of Education x Income [Absolute]', fontsize = 17)
plt.savefig("EIR_regDataPosterior.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_EIR_plot['corr_diff_prior_post1_notAbs'], y= df_EIR_plot['corr_diff_prior_post2_notAbs'], marker = 'o', s = 200, c='firebrick', alpha=0.6)
plt.xlabel('Posterior 1 - Prior', fontsize = 17)
plt.ylabel('Posterior 2 - Prior', fontsize = 17)
plt.title('Years of Education x Income [Not Absolute]', fontsize = 17)
plt.savefig("EIR_comparePriorPosterior_notAbs.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_EIR_plot['corr_diff_prior_post1_notAbs'], y= df_EIR_plot['corr_diff_prior_post2_notAbs'], marker = 'o', s = 200, c='firebrick', alpha=0.6)
sns.regplot(df_EIR_plot.corr_diff_prior_post1_notAbs, df_EIR_plot.corr_diff_prior_post2_notAbs, ci=None)

plt.xlabel('Posterior 1 - Prior', fontsize = 17)
plt.ylabel('Posterior 2 - Prior', fontsize = 17)
plt.title('Years of Education x Income [Not Absolute]', fontsize = 17)
plt.savefig("EIR_regPriorPosterior_notAbs.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_EIR_plot['corr_diff_data_post1_notAbs'], y= df_EIR_plot['corr_diff_data_post2_notAbs'], marker = 'o', s = 200, c='navy', alpha=0.6)
plt.xlabel('Posterior 1 - Data', fontsize = 17)
plt.ylabel('Posterior 2 - Data', fontsize = 17)
plt.title('Years of Education x Income [Not Absolute]', fontsize = 17)
plt.savefig("EIR_compareDataPosterior_notAbs.png")

# %%
plt.figure(figsize = (10,8))

plt.scatter(x = df_EIR_plot['corr_diff_data_post1_notAbs'], y= df_EIR_plot['corr_diff_data_post2_notAbs'], marker = 'o', s = 200, c='navy', alpha=0.6)
sns.regplot(df_EIR_plot.corr_diff_data_post1_notAbs, df_EIR_plot.corr_diff_data_post2_notAbs, ci=None)

plt.xlabel('Posterior 1 - Data', fontsize = 17)
plt.ylabel('Posterior 2 - Data', fontsize = 17)
plt.title('Years of Education x Income [Not Absolute]', fontsize = 17)
plt.savefig("EIR_regDataPosterior_notAbs.png")

# %%
import matplotlib.pyplot as plt

plt.figure()
# Hold activation for multiple lines on same graph
# plt.hold('on')
# Set x-axis range
plt.xlim((1,9))
# Set y-axis range
plt.ylim((1,9))
# Draw lines to split quadrants
plt.plot([5,5],[1,9], linewidth=4, color='red' )
plt.plot([1,9],[5,5], linewidth=4, color='red' )
plt.title('Quadrant plot')
# Draw some sub-regions in upper left quadrant
plt.plot([3,3],[5,9], linewidth=2, color='blue')
plt.plot([1,5],[7,7], linewidth=2, color='blue')
plt.show()
